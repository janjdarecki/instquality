# %%
import pandas as pd

from functions.utils import *

# %%
df = pd.read_pickle("pickles/inst.dat")
df
# Out:
#            country  year iso_code_1 iso_code_2          region  \
# 0      Afghanistan  1960         AF        AFG   Southern Asia
# 1      Afghanistan  1961         AF        AFG   Southern Asia
# 2      Afghanistan  1962         AF        AFG   Southern Asia
# 3      Afghanistan  1963         AF        AFG   Southern Asia
# 4      Afghanistan  1964         AF        AFG   Southern Asia
# ...            ...   ...        ...        ...             ...
# 11184     Zimbabwe  2019         ZW        ZWE  Eastern Africa
# 11185     Zimbabwe  2020         ZW        ZWE  Eastern Africa
# 11186     Zimbabwe  2021         ZW        ZWE  Eastern Africa
# 11187     Zimbabwe  2022         ZW        ZWE  Eastern Africa
# 11188     Zimbabwe  2023         ZW        ZWE  Eastern Africa
#
#        efw_economic_freedom_summary_index  efw_rank  efw_quartile  \
# 0                                     NaN       NaN           NaN
# 1                                     NaN       NaN           NaN
# ...
