# %%
import pandas as pd
import numpy as np
from functools import reduce
import difflib
from datetime import datetime
from concurrent.futures import ProcessPoolExecutor
import warnings; warnings.filterwarnings("ignore")

# %% [markdown]
# ## Functions

# %%
def merge_country_observations_old(df, name1_list, name2_list):
    now = datetime.now()
    print(name1_list, name2_list)
    numeric_columns = df.select_dtypes(include=['number']).columns
    for column in numeric_columns:
        for year in df['year'].unique():
            mean_values = df[(df['country'].isin(name2_list)) & (df['year'] == year)][column].mean()
            for country in name1_list:
                df.loc[(df['country'] == country) & (df['year'] == year), column] = df.loc[(df['country'] == country) & (df['year'] == year), column].fillna(mean_values)
    df = df.drop(df[df['country'].isin(name2_list)].index)
    then = datetime.now()
    print('Elapsed time:', (then - now).total_seconds() / 60, 'minutes')
    return df

def merge_country_observations(df, name1_list, name2_list):
    now = datetime.now()
    print(name1_list, name2_list)
    numeric_columns = df.select_dtypes(include=['number']).columns
    mean_values_by_year = df[df['country'].isin(name2_list)].groupby('year')[numeric_columns].mean()
    for country in name1_list:
        for column in numeric_columns:
            df.loc[df['country'] == country, column] = df.loc[df['country'] == country].apply(
                lambda row: row[column] 
                if pd.notna(row[column]) 
                else mean_values_by_year.loc[row['year'], column] 
                if row['year'] in mean_values_by_year.index else np.nan,  # Handle missing years
                axis=1)
    df = df[~df['country'].isin(name2_list)]
    then = datetime.now()
    print('Elapsed time:', (then - now).total_seconds(), 'seconds')
    return df

    
def standardize_dataframe(df, target, exclude=None):
    exclude = exclude or []
    for col in df.columns:
        if col != target and col not in exclude and pd.api.types.is_numeric_dtype(df[col]):
            m, s = df[col].mean(), df[col].std()
            df[col] = (df[col] - m) / s if s != 0 else 0
    return df

# %% [markdown]
# # Load, merge and clean

# %% [markdown]
# ## Load

# %% [markdown]
# ### Corruption perceptions index (only 2022 tho)
# ISO3

# %%
cpi = pd.read_excel("IQD/CPI.xlsx", header=2)
cpi.columns = (
    cpi.columns.str.strip()      
    .str.lower()             
    .str.replace(' ', '_')           
    .str.replace('[^a-z0-9_]', ''))
cpi = cpi.rename(columns={'country_/_territory':'country'})
cpi['year'] = 2022
cpi
# Out:
#          country iso3 region  cpi_score_2022  rank  standard_error  \
# 0    Afghanistan  AFG     AP              24   150        6.299999
# 1        Albania  ALB    ECA              36   101        1.316355
# 2        Algeria  DZA   MENA              33   116        1.673809
# 3         Angola  AGO    SSA              33   116        2.807703
# 4      Argentina  ARG    AME              38    94        2.334808
# ..           ...  ...    ...             ...   ...             ...
# 175    Venezuela  VEN    AME              14   177        1.296945
# 176      Vietnam  VNM     AP              42    77        1.497007
# 177        Yemen  YEM   MENA              16   176        1.975074
# 178       Zambia  ZMB    SSA              33   116        1.495884
# 179     Zimbabwe  ZWE    SSA              23   157        1.532080
#
#      number_of_sources  lower_ci  upper_ci  african_development_bank_cpia  \
# 0                    4  13.66800  34.33200                            NaN
# 1                    8  33.84118  38.15882                            NaN
# 2                    6  30.25495  35.74504                            NaN
# 3                    7  28.39537  37.60463                            NaN
# 4                    7  34.17091  41.82909                            NaN
# ..                 ...       ...       ...                            ...
# 175                  8  11.87301  16.12699                            NaN
# 176                  8  39.54491  44.45509                            NaN
# 177                  7  12.76088  19.23912                            NaN
# 178                  9  30.54675  35.45325                           34.0
# 179                  8  20.48739  25.51261                           19.0
#
#      ...  freedom_house_nations_in_transit  \
# 0    ...                               NaN
# 1    ...                              42.0
# 2    ...                               NaN
# 3    ...                               NaN
# 4    ...                               NaN
# ..   ...                               ...
# 175  ...                               NaN
# 176  ...                               NaN
# 177  ...                               NaN
# 178  ...                               NaN
# 179  ...                               NaN
#
#      global_insights_country_risk_ratings  imd_world_competitiveness_yearbook  \
# 0                                      10                                 NaN
# 1                                      35                                 NaN
# 2                                      35                                 NaN
# 3                                      47                                 NaN
# 4                                      35                                24.0
# ..                                    ...                                 ...
# 175                                    10                                24.0
# 176                                    47                                 NaN
# 177                                    10                                 NaN
# 178                                    35                                 NaN
# 179                                    22                                 NaN
#
#      perc_asia_risk_guide  prs_international_country_risk_guide  \
# 0                     NaN                                   NaN
# 1                     NaN                                  32.0
# 2                     NaN                                  24.0
# 3                     NaN                                  32.0
# 4                     NaN                                  32.0
# ..                    ...                                   ...
# 175                   NaN                                  15.0
# 176                  39.0                                  41.0
# 177                   NaN                                  15.0
# 178                   NaN                                  32.0
# 179                   NaN                                  15.0
#
#      varieties_of_democracy_project  world_bank_cpia  \
# 0                              43.0              NaN
# 1                              27.0              NaN
# 2                              29.0              NaN
# 3                              46.0              NaN
# 4                              47.0              NaN
# ..                              ...              ...
# 175                             9.0              NaN
# 176                            44.0              NaN
# 177                            11.0             10.0
# 178                            49.0             27.0
# 179                            20.0             27.0
#
#      world_economic_forum_eos  world_justice_project_rule_of_law_index  year
# 0                         NaN                                     16.0  2022
# 1                        42.0                                     29.0  2022
# 2                         NaN                                     36.0  2022
# 3                        22.0                                     28.0  2022
# 4                         NaN                                     44.0  2022
# ..                        ...                                      ...   ...
# 175                      13.0                                      9.0  2022
# 176                      55.0                                     36.0  2022
# 177                      30.0                                      NaN  2022
# 178                      30.0                                     36.0  2022
# 179                       NaN                                     23.0  2022
#
# [180 rows x 23 columns]

# %% [markdown]
# ### Economic freedom in the world
# ISO2, ISO3

# %%
efw = pd.read_excel("IQD/EFW.xlsx", header=4, usecols=lambda col: col != 'Unnamed: 0')
efw.columns = (
    efw.columns.str.strip()      
    .str.lower()             
    .str.replace(' ', '_')           
    .str.replace('[^a-z0-9_]', ''))
efw = efw.rename(columns={'countries':'country'})
efw
# Out:
#       year iso_code_2 iso_code_3        country  \
# 0     2021         AL        ALB        Albania
# 1     2021         DZ        DZA        Algeria
# 2     2021         AO        AGO         Angola
# 3     2021         AR        ARG      Argentina
# 4     2021         AM        ARM        Armenia
# ...    ...        ...        ...            ...
# 4615  1970         VE        VEN  Venezuela, RB
# 4616  1970         VN        VNM        Vietnam
# 4617  1970         YE        YEM    Yemen, Rep.
# 4618  1970         ZM        ZMB         Zambia
# 4619  1970         ZW        ZWE       Zimbabwe
#
#       economic_freedom_summary_index   rank  quartile  \
# 0                               7.60   31.0       1.0
# 1                               4.82  157.0       4.0
# 2                               5.38  149.0       4.0
# 3                               4.77  158.0       4.0
# 4                               7.58   33.0       1.0
# ...                              ...    ...       ...
# 4615                            7.29   14.0       1.0
# 4616                             NaN    NaN       NaN
# 4617                             NaN    NaN       NaN
# 4618                            5.26   61.0       3.0
# 4619                             NaN    NaN       NaN
#
#       1a_government_consumption       data  1b__transfers_and_subsidies  ...  \
# 0                      7.758824  13.620000                     7.133515  ...
# 1                      3.467647  28.210000                     7.817129  ...
# 2                      7.179412  15.590000                     9.702997  ...
# 3                      5.691176  20.650000                     5.536785  ...
# 4                      6.473529  17.990000                     7.316076  ...
# ...                         ...        ...                          ...  ...
# 4615                   6.602003  17.553191                     9.827430  ...
# 4616                        NaN        NaN                          NaN  ...
# 4617                        NaN        NaN                          NaN  ...
# 4618                   3.448131  28.276353                     9.105430  ...
# 4619                   7.806922  13.456464                          NaN  ...
#
#       5civ_tax_compliance  5c__business_regulations  5di__market_openness  \
# 0                3.587625                  5.312221              6.810619
# 1                4.764764                  3.735188              4.412430
# 2                4.641462                  4.285256              3.099164
# 3                4.504147                  4.862998              6.144822
# 4                6.020369                  5.556860              5.590883
# ...                   ...                       ...                   ...
# 4615                  NaN                  6.335000                   NaN
# 4616                  NaN                  2.550000                   NaN
# 4617                  NaN                  5.017500                   NaN
# 4618                  NaN                  6.067500                   NaN
# 4619                  NaN                  0.497500                   NaN
#
#       5dii_business_permits 5diii_distorton_of_the_business_environment  \
# 0                  5.621940                                    6.250000
# 1                  8.771111                                    3.134281
# 2                  7.916416                                    1.250000
# 3                  5.726521                                    2.922359
# 4                  9.302574                                    5.000000
# ...                     ...                                         ...
# 4615                    NaN                                         NaN
# 4616                    NaN                                         NaN
# 4617                    NaN                                         NaN
# 4618                    NaN                                         NaN
# 4619                    NaN                                         NaN
#
#       5d_freedom_to_enter_markets_and_compete 5__regulation  area_5_rank  \
# 0                                    6.227520      6.972552         51.0
# 1                                    5.439274      4.836754        150.0
# 2                                    4.088527      4.730618        153.0
# 3                                    4.931234      5.299677        143.0
# 4                                    6.631152      6.939219         52.0
# ...                                       ...           ...          ...
# 4615                                      NaN      6.545577         35.0
# 4616                                      NaN           NaN          NaN
# 4617                                      NaN           NaN          NaN
# 4618                                      NaN      6.697414         32.0
# 4619                                      NaN           NaN          NaN
#
#                   world_bank_region  \
# 0             Europe & Central Asia
# 1        Middle East & North Africa
# 2                Sub-Saharan Africa
# 3     Latin America & the Caribbean
# 4             Europe & Central Asia
# ...                             ...
# 4615  Latin America & the Caribbean
# 4616            East Asia & Pacific
# 4617     Middle East & North Africa
# 4618             Sub-Saharan Africa
# 4619             Sub-Saharan Africa
#
#       world_bank_current_income_classification,_1990-present
# 0                                                    UM
# 1                                                    LM
# 2                                                    LM
# 3                                                    UM
# 4                                                    UM
# ...                                                 ...
# 4615                                                NaN
# 4616                                                NaN
# 4617                                                NaN
# 4618                                                NaN
# 4619                                                NaN
#
# [4620 rows x 85 columns]

# %% [markdown]
# ### Freedom in the world

# %%
# Load
fiw1 = pd.read_excel("IQD/FIW.xlsx", sheet_name='FIW06-23').rename(columns={'country/territory':'country'})
fiw1.columns = (
    fiw1.columns.str.strip()      
    .str.lower()             
    .str.replace(' ', '_')           
    .str.replace('[^a-z0-9_]', ''))
fiw1 = fiw1.rename(columns={'country/territory':'country'})

fiw2 = pd.read_excel("IQD/FIW.xlsx", sheet_name='FIW03-05')
fiw2.columns = (
    fiw2.columns.str.strip()      
    .str.lower()             
    .str.replace(' ', '_')           
    .str.replace('[^a-z0-9_]', ''))
fiw2 = fiw2.rename(columns={'country/territory':'country'})

# %%
# Adjust fiw2 format
years = ['03', '04', '05']
rows = []
for index, row in fiw2.iterrows():
    for year in years:
        # Create a new row for each year
        new_row = {
            'country': row['country'],
            'region': np.nan,  
            'c/t?': row['c/t?'],
            'edition': int('20' + year),
            'status': np.nan,  
            'pr_rating': np.nan,
            'cl_rating': np.nan,
            'a': np.nan,  
            'b': np.nan,  
            'c': np.nan, 
            'add_q': np.nan,  
            'add_a': np.nan,  
            'pr': row[f'fiw{year}_pr'],
            'd': np.nan,  
            'e': np.nan,  
            'f': np.nan,  
            'g': np.nan,  
            'cl': row[f'fiw{year}_cl'],
            'total': row[f'fiw{year}_total'],}
        rows.append(new_row)
fiw2 = pd.DataFrame(rows)

# %%
# concat
fiw = pd.concat([fiw1, fiw2], ignore_index=True)
fiw = fiw.rename(columns={'edition':'year'})
fiw = fiw.sort_values(by=['country', 'year']).reset_index(drop=True)
fiw
# Out:
#        country   region c/t?  year status  pr_rating  cl_rating    a    b  \
# 0     Abkhazia      NaN    t  2003    NaN        NaN        NaN  NaN  NaN
# 1     Abkhazia      NaN    t  2004    NaN        NaN        NaN  NaN  NaN
# 2     Abkhazia      NaN    t  2005    NaN        NaN        NaN  NaN  NaN
# 3     Abkhazia  Eurasia    t  2006     PF        5.0        5.0  5.0  5.0
# 4     Abkhazia  Eurasia    t  2007     PF        5.0        5.0  5.0  5.0
# ...        ...      ...  ...   ...    ...        ...        ...  ...  ...
# 4375  Zimbabwe   Africa    c  2019     PF        5.0        5.0  3.0  6.0
# 4376  Zimbabwe   Africa    c  2020     PF        5.0        5.0  3.0  6.0
# 4377  Zimbabwe   Africa    c  2021     NF        6.0        5.0  3.0  5.0
# 4378  Zimbabwe   Africa    c  2022     NF        6.0        5.0  3.0  5.0
# 4379  Zimbabwe   Africa    c  2023     NF        6.0        5.0  3.0  5.0
#
#         c  add_q  add_a  pr    d    e    f    g  cl total
# 0     NaN    NaN    NaN   9  NaN  NaN  NaN  NaN  20    29
# 1     NaN    NaN    NaN   9  NaN  NaN  NaN  NaN  21    30
# 2     NaN    NaN    NaN   9  NaN  NaN  NaN  NaN  21    30
# 3     3.0    0.0    0.0  13  8.0  4.0  4.0  5.0  21    34
# 4     3.0    0.0    0.0  13  8.0  4.0  4.0  5.0  21    34
# ...   ...    ...    ...  ..  ...  ...  ...  ...  ..   ...
# 4375  3.0    0.0    NaN  12  8.0  4.0  2.0  5.0  19    31
# 4376  3.0    0.0    NaN  12  7.0  3.0  2.0  5.0  17    29
# 4377  3.0    0.0    NaN  11  7.0  3.0  2.0  5.0  17    28
# 4378  3.0    0.0    NaN  11  7.0  3.0  2.0  5.0  17    28
# 4379  3.0    0.0    NaN  11  7.0  3.0  2.0  5.0  17    28
#
# [4380 rows x 19 columns]

# %% [markdown]
# ### Index of economic freedom
# ISO Code

# %%
ief = pd.read_csv("IQD/IEF.csv", usecols=lambda col: col != 'Id')
ief.columns = (
    ief.columns.str.strip()      
    .str.lower()             
    .str.replace(' ', '_')           
    .str.replace('[^a-z0-9_]', ''))
ief = ief.rename(columns={'name':'country',
                          'index_year':'year'})
ief = ief.sort_values(by=['country', 'year']).reset_index(drop=True)
ief
# Out:
#           country   short_name iso_code  year  overall_score  property_rights  \
# 0     Afghanistan  Afghanistan       AF  1995            NaN              NaN
# 1     Afghanistan  Afghanistan       AF  1996            NaN              NaN
# 2     Afghanistan  Afghanistan       AF  1997            NaN              NaN
# 3     Afghanistan  Afghanistan       AF  1998            NaN              NaN
# 4     Afghanistan  Afghanistan       AF  1999            NaN              NaN
# ...           ...          ...      ...   ...            ...              ...
# 5334     Zimbabwe     Zimbabwe       ZW  2019           40.4             29.7
# 5335     Zimbabwe     Zimbabwe       ZW  2020           43.1             33.7
# 5336     Zimbabwe     Zimbabwe       ZW  2021           39.5             32.6
# 5337     Zimbabwe     Zimbabwe       ZW  2022           33.1             20.8
# 5338     Zimbabwe     Zimbabwe       ZW  2023           39.0             20.0
#
#       judicial_effectiveness  government_integrity  tax_burden  \
# 0                        NaN                   NaN         NaN
# 1                        NaN                   NaN         NaN
# 2                        NaN                   NaN         NaN
# 3                        NaN                   NaN         NaN
# 4                        NaN                   NaN         NaN
# ...                      ...                   ...         ...
# 5334                    24.8                  15.8        62.3
# 5335                    28.3                  18.9        62.3
# 5336                    32.0                  21.3        63.4
# 5337                    16.3                  20.6        66.1
# 5338                    15.8                  20.0        65.8
#
#       government_spending  fiscal_health  business_freedom  labor_freedom  \
# 0                     NaN            NaN               NaN            NaN
# 1                     NaN            NaN               NaN            NaN
# 2                     NaN            NaN               NaN            NaN
# 3                     NaN            NaN               NaN            NaN
# 4                     NaN            NaN               NaN            NaN
# ...                   ...            ...               ...            ...
# 5334                 74.5           23.7              33.4           43.3
# 5335                 88.0           36.2              39.1           43.1
# 5336                 89.4           58.8              41.5           44.1
# 5337                 87.2           79.8              36.9           34.9
# 5338                 92.6           89.9              39.8           35.4
#
#       monetary_freedom  trade_freedom  investment_freedom  financial_freedom
# 0                  NaN            NaN                 NaN                NaN
# 1                  NaN            NaN                 NaN                NaN
# 2                  NaN            NaN                 NaN                NaN
# 3                  NaN            NaN                 NaN                NaN
# 4                  NaN            NaN                 NaN                NaN
# ...                ...            ...                 ...                ...
# 5334              72.4           70.0                25.0               10.0
# 5335              62.8           70.0                25.0               10.0
# 5336               0.0           56.0                25.0               10.0
# 5337               0.1            0.1                25.0               10.0
# 5338               0.1           54.0                25.0               10.0
#
# [5339 rows x 17 columns]

# %% [markdown]
# ### Polity 5D

# %%
p5d = pd.read_excel("IQD/P5D.xls")
p5d = p5d[p5d.year>=1960].reset_index(drop=True)
p5d
# Out:
#       p5    cyear  ccode scode      country  year  flag  fragment  democ  \
# 0      0  7001960    700   AFG  Afghanistan  1960     0       NaN      0
# 1      0  7001961    700   AFG  Afghanistan  1961     0       NaN      0
# 2      0  7001962    700   AFG  Afghanistan  1962     0       NaN      0
# 3      0  7001963    700   AFG  Afghanistan  1963     0       NaN      0
# 4      0  7001964    700   AFG  Afghanistan  1964     0       NaN      0
# ...   ..      ...    ...   ...          ...   ...   ...       ...    ...
# 8795   1  5522014    552   ZIM     Zimbabwe  2014     0       0.0      5
# 8796   1  5522015    552   ZIM     Zimbabwe  2015     0       0.0      5
# 8797   1  5522016    552   ZIM     Zimbabwe  2016     0       0.0      5
# 8798   1  5522017    552   ZIM     Zimbabwe  2017     0       0.0      5
# 8799   1  5522018    552   ZIM     Zimbabwe  2018     0       0.0      5
#
#       autoc  ...  interim  bmonth  bday   byear  bprec  post  change   d5  sf  \
# 0        10  ...      NaN     NaN   NaN     NaN    NaN   NaN     NaN  NaN NaN
# 1        10  ...      NaN     NaN   NaN     NaN    NaN   NaN     NaN  NaN NaN
# 2        10  ...      NaN     NaN   NaN     NaN    NaN   NaN     NaN  NaN NaN
# 3        10  ...      NaN     NaN   NaN     NaN    NaN   NaN     NaN  NaN NaN
# 4         7  ...      NaN     9.0  10.0  1964.0    1.0  -7.0     3.0  1.0 NaN
# ...     ...  ...      ...     ...   ...     ...    ...   ...     ...  ...  ..
# 8795      1  ...      NaN     NaN   NaN     NaN    NaN   NaN     NaN  NaN NaN
# 8796      1  ...      NaN     NaN   NaN     NaN    NaN   NaN     NaN  NaN NaN
# 8797      1  ...      NaN     NaN   NaN     NaN    NaN   NaN     NaN  NaN NaN
# 8798      1  ...      NaN     NaN   NaN     NaN    NaN   NaN     NaN  NaN NaN
# 8799      1  ...      NaN     NaN   NaN     NaN    NaN   NaN     NaN  NaN NaN
#
#       regtrans
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          1.0
# ...        ...
# 8795       NaN
# 8796       NaN
# 8797       NaN
# 8798       NaN
# 8799       NaN
#
# [8800 rows x 37 columns]

# %% [markdown]
# ### Political terror scale

# %%
pts = pd.read_excel("IQD/PTS.xlsx")
pts.columns = (
    pts.columns.str.strip()      
    .str.lower()             
    .str.replace(' ', '_')           
    .str.replace('[^a-z0-9_]', ''))
pts
# Out:
#            country  country_old  year cow_code_a  cow_code_n wordbank_code_a  \
# 0      Afghanistan  Afghanistan  1976        AFG       700.0             AFG
# 1      Afghanistan  Afghanistan  1977        AFG       700.0             AFG
# 2      Afghanistan  Afghanistan  1978        AFG       700.0             AFG
# 3      Afghanistan  Afghanistan  1979        AFG       700.0             AFG
# 4      Afghanistan  Afghanistan  1980        AFG       700.0             AFG
# ...            ...          ...   ...        ...         ...             ...
# 10002     Zimbabwe     Zimbabwe  2018        ZIM       552.0             ZWE
# 10003     Zimbabwe     Zimbabwe  2019        ZIM       552.0             ZWE
# 10004     Zimbabwe     Zimbabwe  2020        ZIM       552.0             ZWE
# 10005     Zimbabwe     Zimbabwe  2021        ZIM       552.0             ZWE
# 10006     Zimbabwe     Zimbabwe  2022        ZIM       552.0             ZWE
#
#        un_code_n region  pts_a  pts_h  pts_s  na_status_a  na_status_h  \
# 0            4.0     sa    2.0    NaN    2.0            0           88
# 1            4.0     sa    4.0    NaN    2.0            0           88
# 2            4.0     sa    4.0    NaN    3.0            0           88
# 3            4.0     sa    5.0    NaN    5.0            0           88
# 4            4.0     sa    5.0    NaN    5.0            0           88
# ...          ...    ...    ...    ...    ...          ...          ...
# 10002      716.0    ssa    NaN    3.0    3.0           88            0
# 10003      716.0    ssa    3.0    4.0    3.0            0            0
# 10004      716.0    ssa    3.0    4.0    3.0            0            0
# 10005      716.0    ssa    3.0    3.0    3.0            0            0
# 10006      716.0    ssa    3.0    3.0    3.0            0            0
#
#        na_status_s
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 10002            0
# 10003            0
# 10004            0
# 10005            0
# 10006            0
#
# [10007 rows x 14 columns]

# %% [markdown]
# ### World governance indicators

# %%
def prep_wgi(sheet_name):
    # Load
    df = pd.read_excel("IQD/WGI.xlsx", sheet_name=sheet_name, header=[13, 14])
    
    # Prep
    df.columns = [' '.join(map(str, col)).strip() for col in df.columns.values]
    df = df.rename(columns={'Unnamed: 0_level_0 Country/Territory':'country',
                            'Unnamed: 1_level_0 Code':'code'})
    df_long = pd.melt(df, id_vars=['country', 'code'], var_name='Year_Metric', value_name='Value')
    df_long['Year'] = df_long['Year_Metric'].str.extract('(\d+)')[0]  # Extract year part
    df_long['Metric'] = df_long['Year_Metric'].str.split(' ').str[1]  # Extract metric name
    df_long = df_long.drop(columns=['Year_Metric'])
    df_long = df_long[['country', 'code', 'Year', 'Metric', 'Value']]
    
    # Pivot
    df_wide = df_long.pivot_table(
        index=['country', 'code', 'Year'],  # Columns to keep, not to spread
        columns='Metric',  # Column to spread
        values='Value',  # Fill values
        aggfunc='first'  # Function to aggregate values, 'first' because each combination is unique
    )
    df_wide.reset_index(inplace=True)
    df_wide.columns.name = None
    df_wide.rename(columns={col: f"{sheet_name}_{col}" for col in df_wide.columns if col not in ['country', 'code', 'Year']}, inplace=True)
    return df_wide

# %%
# Load
wgi1 = prep_wgi(sheet_name="VoiceandAccountability")
wgi2 = prep_wgi(sheet_name="Political StabilityNoViolence")
wgi3 = prep_wgi(sheet_name="GovernmentEffectiveness")
wgi4 = prep_wgi(sheet_name="RegulatoryQuality")
wgi5 = prep_wgi(sheet_name="RuleofLaw")
wgi6 = prep_wgi(sheet_name="ControlofCorruption")

# Merge
dataframes = [wgi1, wgi2, wgi3, wgi4, wgi5, wgi6]
wgi = reduce(lambda left, right: pd.merge(left, right, on=['country', 'code', 'Year'], how='left'), dataframes)

# %%
# Final
wgi.columns = (
    wgi.columns.str.strip()      
    .str.lower()             
    .str.replace(' ', '_')           
    .str.replace('[^a-z0-9_]', ''))
wgi = wgi.rename(columns={'Year':'year'})
wgi = wgi.sort_values(by=['country', 'year']).reset_index(drop=True)
wgi
# Out:
#           country code  year  voiceandaccountability_estimate  \
# 0     Afghanistan  AFG  1996                        -1.908540
# 1     Afghanistan  AFG  1998                        -2.039301
# 2     Afghanistan  AFG  2000                        -2.031417
# 3     Afghanistan  AFG  2002                        -1.433421
# 4     Afghanistan  AFG  2003                        -1.177571
# ...           ...  ...   ...                              ...
# 4970     Zimbabwe  ZWE  2018                        -1.136798
# 4971     Zimbabwe  ZWE  2019                        -1.163669
# 4972     Zimbabwe  ZWE  2020                        -1.113408
# 4973     Zimbabwe  ZWE  2021                        -1.135830
# 4974     Zimbabwe  ZWE  2022                        -1.102206
#
#       voiceandaccountability_lower  voiceandaccountability_numsrc  \
# 0                         0.000000                            4.0
# 1                         0.000000                            4.0
# 2                         0.000000                            4.0
# 3                         2.985075                            6.0
# 4                         6.965174                            5.0
# ...                            ...                            ...
# 4970                     12.135922                           15.0
# 4971                     12.077294                           14.0
# 4972                     13.043478                           13.0
# 4973                     12.560387                           13.0
# 4974                     13.043478                           13.0
#
#       voiceandaccountability_rank  voiceandaccountability_stderr  \
# 0                        1.000000                       0.261457
# 1                        0.497512                       0.256090
# 2                        0.995025                       0.254043
# 3                        9.452736                       0.189453
# 4                       14.427860                       0.207045
# ...                           ...                            ...
# 4970                    16.990292                       0.123724
# 4971                    16.425121                       0.117815
# 4972                    17.874395                       0.120230
# 4973                    18.357489                       0.120300
# 4974                    18.840580                       0.119338
#
#       voiceandaccountability_upper  political_stabilitynoviolence_estimate  \
# 0                         9.500000                               -2.417310
# 1                         4.975124                               -2.427355
# 2                         5.472637                               -2.438969
# 3                        14.925373                               -2.035034
# 4                        24.378109                               -2.198372
# ...                            ...                                     ...
# 4970                     21.844660                               -0.721038
# 4971                     21.256039                               -0.943286
# 4972                     23.188406                               -1.052728
# 4973                     22.705315                               -0.954426
# 4974                     23.188406                               -0.884500
#
#       ...  ruleoflaw_numsrc  ruleoflaw_rank  ruleoflaw_stderr  \
# 0     ...               3.0        1.507538          0.350509
# 1     ...               3.0        2.000000          0.327277
# 2     ...               3.0        1.492537          0.291758
# 3     ...               4.0        1.990050          0.296793
# 4     ...               4.0        2.985075          0.300880
# ...   ...               ...             ...               ...
# 4970  ...              15.0        8.095238          0.138192
# 4971  ...              15.0        7.142857          0.140278
# 4972  ...              13.0        7.619048          0.139408
# 4973  ...              13.0        8.571428          0.146504
# 4974  ...              13.0       11.320755          0.148795
#
#       ruleoflaw_upper  controlofcorruption_estimate  \
# 0           12.562814                     -1.291705
# 1           11.500000                     -1.176012
# 2            9.452736                     -1.271724
# 3           11.442786                     -1.251137
# 4           16.417910                     -1.344180
# ...               ...                           ...
# 4970        14.285714                     -1.246001
# 4971        13.809524                     -1.271190
# 4972        12.857142                     -1.287992
# 4973        15.714286                     -1.253550
# 4974        17.924528                     -1.255139
#
#       controlofcorruption_lower  controlofcorruption_numsrc  \
# 0                      0.000000                         2.0
# 1                      0.000000                         2.0
# 2                      0.000000                         2.0
# 3                      0.000000                         2.0
# 4                      0.000000                         3.0
# ...                         ...                         ...
# 4970                   6.190476                        15.0
# 4971                   4.761905                        15.0
# 4972                   4.285714                        13.0
# 4973                   4.285714                        12.0
# 4974                   4.245283                        12.0
#
#       controlofcorruption_rank  controlofcorruption_stderr  \
# 0                     4.301075                    0.340507
# 1                     8.021390                    0.324013
# 2                     4.787234                    0.346906
# 3                     4.761905                    0.352838
# 4                     4.761905                    0.270215
# ...                        ...                         ...
# 4970                 10.000000                    0.125007
# 4971                 10.000000                    0.133336
# 4972                 10.000000                    0.140076
# 4973                 10.000000                    0.151591
# 4974                  8.490566                    0.151262
#
#       controlofcorruption_upper
# 0                     27.419355
# 1                     33.689838
# 2                     30.851065
# 3                     32.804234
# 4                     19.047619
# ...                         ...
# 4970                  13.809524
# 4971                  14.285714
# 4972                  16.190475
# 4973                  17.619047
# 4974                  17.924528
#
# [4975 rows x 39 columns]

# %% [markdown]
# ### World bank data

# %%
# Load
wb = pd.read_csv("nasdaq/WB.csv")

# Pre-process
wb = wb[wb.year.notnull()]
wb['year'] = wb['year'].astype(int)
wb = wb.rename(columns={"series_id": "indicator"})
wb['country_name'] = wb['country_name'].replace('Czechia', 'Czech Republic')
wb['country_name'] = wb['country_name'].replace("Korea, Dem. Peopleâ\x80\x99s Rep.", "Korea, Dem. People's Rep.")

# Pivot
wb = wb.pivot_table(index=['country_code', 'country_name', 'year'], columns='indicator', values='value').reset_index()

# Other fixes
wb.columns.name = None
wb_prep = wb.rename(columns={'country_name':'country'})

# Drop cols with more than 80 percent NaNs
threshold = 0.2 * len(wb_prep)
wb = wb_prep.dropna(axis=1, thresh=threshold)
print("We have dropped", len(wb_prep.columns)-len(wb.columns),"columns with more than 80 percent NaN observations -", len(wb.columns), "remain.")
# Out:
# We have dropped 529 columns with more than 80 percent NaN observations - 257 remain.

# %% [markdown]
# ## Merge

# %% [markdown]
# ### CPI + EFW

# %%
set(cpi.columns).intersection(efw.columns)
# Out:
# {'country', 'rank', 'year'}

# %%
cpi = cpi.rename(columns={'rank':'cpi_rank'})
efw = efw.rename(columns={'rank':'efw_rank'})

# %%
country_mapping = {
    'Bahamas': 'Bahamas, The',
    'Cote d\'Ivoire': "Côte d'Ivoire",
    'Guinea Bissau': 'Guinea-Bissau',
    'Korea, North': 'North Korea',
    'Korea, South': 'South Korea',
    'United States of America': 'United States',
    'Russia': 'Russian Federation',
    'Sao Tome and Principe': 'São Tomé and Príncipe',
    'Gambia': 'Gambia, The',
    'Hong Kong': 'Hong Kong SAR, China',
    'Iran': 'Iran, Islamic Rep.',
    'Egypt': 'Egypt, Arab Rep.',
    'Laos': 'Lao PDR',
    'Venezuela': 'Venezuela, RB',
    'Syria': 'Syrian Arab Republic',
    'Turkey': 'Türkiye',
    'Yemen': 'Yemen, Rep.',
    'Congo': 'Congo, Rep.',
    'Democratic Republic of the Congo': 'Congo, Dem. Rep.',
    'Korea, Rep.': 'South Korea',
    'Kyrgyz Republic': 'Kyrgyzstan',
    'Slovak Republic': 'Slovakia'
}

cpi['country'] = cpi['country'].replace(country_mapping)
efw['country'] = efw['country'].replace(country_mapping)

df1 = pd.merge(efw, cpi, on=['country', 'year'], how='outer')

def check_countries(column, min_length=4):
    similar_pairs = []
    for i in range(len(column)):
        for j in range(i + 1, len(column)):
            if column[i] != column[j]:  # Ensure that identical countries are excluded
                seq = difflib.SequenceMatcher(None, column[i], column[j])
                match = seq.find_longest_match(0, len(column[i]), 0, len(column[j]))
                if match.size >= min_length:
                    similar_pairs.append((column[i], column[j], column[i][match.a: match.a + match.size]))
    return similar_pairs

check_countries(df1['country'].unique())
# Out:
# [('Albania', 'Lithuania', 'ania'),
#  ('Albania', 'Mauritania', 'ania'),
#  ('Albania', 'Romania', 'ania'),
#  ('Albania', 'Tanzania', 'ania'),
#  ('Algeria', 'Liberia', 'eria'),
#  ('Algeria', 'Nigeria', 'geria'),
#  ('Angola', 'Mongolia', 'ngol'),
#  ('Armenia', 'Slovenia', 'enia'),
#  ('Armenia', 'Turkmenistan', 'meni'),
#  ('Australia', 'Austria', 'Austr'),
#  ('Australia', 'Central African Republic', 'tral'),
#  ('Australia', 'Somalia', 'alia'),
#  ('Bahamas, The', 'Gambia, The', ', The'),
#  ('Bahrain', 'Ukraine', 'rain'),
#  ('Belarus', 'Brunei Darussalam', 'arus'),
#  ('Bosnia and Herzegovina', 'Trinidad and Tobago', ' and '),
#  ('Bosnia and Herzegovina', 'Saint Vincent and the Grenadines', ' and '),
#  ('Bosnia and Herzegovina', 'São Tomé and Príncipe', ' and '),
#  ('Canada', 'Grenada', 'nada'),
#  ('Central African Republic', 'Congo, Dem. Rep.', ' Rep'),
#  ('Central African Republic', 'Congo, Rep.', ' Rep'),
#  ('Central African Republic', 'Dominican Republic', 'ican Republic'),
#  ('Central African Republic', 'Egypt, Arab Rep.', ' Rep'),
#  ('Central African Republic', 'Iran, Islamic Rep.', ' Rep'),
#  ('Central African Republic', 'South Africa', ' Africa'),
#  ('Central African Republic', 'Syrian Arab Republic', ' Republic'),
#  ('Central African Republic', 'Yemen, Rep.', ' Rep'),
#  ('China', 'Hong Kong SAR, China', 'China'),
#  ('Colombia', 'Gambia, The', 'mbia'),
#  ('Colombia', 'Zambia', 'mbia'),
#  ('Colombia', 'Solomon Islands', 'olom'),
#  ('Congo, Dem. Rep.', 'Congo, Rep.', 'Congo, '),
#  ('Congo, Dem. Rep.', 'Dominican Republic', ' Rep'),
#  ('Congo, Dem. Rep.', 'Egypt, Arab Rep.', ' Rep.'),
#  ('Congo, Dem. Rep.', 'Iran, Islamic Rep.', ' Rep.'),
#  ('Congo, Dem. Rep.', 'Mongolia', 'ongo'),
#  ('Congo, Dem. Rep.', 'Syrian Arab Republic', ' Rep'),
#  ('Congo, Dem. Rep.', 'Yemen, Rep.', ' Rep.'),
#  ('Congo, Rep.', 'Dominican Republic', ' Rep'),
#  ('Congo, Rep.', 'Egypt, Arab Rep.', ' Rep.'),
#  ('Congo, Rep.', 'Iran, Islamic Rep.', ' Rep.'),
#  ('Congo, Rep.', 'Mongolia', 'ongo'),
#  ('Congo, Rep.', 'Syrian Arab Republic', ' Rep'),
#  ('Congo, Rep.', 'Yemen, Rep.', ', Rep.'),
#  ('Denmark', 'Myanmar', 'nmar'),
#  ('Dominican Republic', 'Egypt, Arab Rep.', ' Rep'),
#  ('Dominican Republic', 'Iran, Islamic Rep.', ' Rep'),
#  ('Dominican Republic', 'Syrian Arab Republic', ' Republic'),
#  ('Dominican Republic', 'Yemen, Rep.', ' Rep'),
#  ('Dominican Republic', 'Dominica', 'Dominica'),
#  ('Ecuador', 'El Salvador', 'ador'),
#  ('Egypt, Arab Rep.', 'Iran, Islamic Rep.', ' Rep.'),
#  ('Egypt, Arab Rep.', 'Saudi Arabia', ' Arab'),
#  ('Egypt, Arab Rep.', 'Syrian Arab Republic', ' Arab Rep'),
#  ('Egypt, Arab Rep.', 'United Arab Emirates', ' Arab '),
#  ('Egypt, Arab Rep.', 'Yemen, Rep.', ' Rep.'),
#  ('Estonia', 'North Macedonia', 'onia'),
#  ('Finland', 'Iceland', 'land'),
#  ('Finland', 'Ireland', 'land'),
#  ('Finland', 'Netherlands', 'land'),
#  ('Finland', 'New Zealand', 'land'),
#  ('Finland', 'Poland', 'land'),
#  ('Finland', 'Switzerland', 'land'),
#  ('Finland', 'Thailand', 'land'),
#  ('Finland', 'Solomon Islands', 'land'),
#  ('Gambia, The', 'Mozambique', 'ambi'),
#  ('Gambia, The', 'Zambia', 'ambia'),
#  ('Guinea', 'Guinea-Bissau', 'Guinea'),
#  ('Guinea', 'Papua New Guinea', 'Guinea'),
#  ('Guinea', 'Equatorial Guinea', 'Guinea'),
#  ('Guinea-Bissau', 'Papua New Guinea', 'Guinea'),
#  ('Guinea-Bissau', 'Equatorial Guinea', 'Guinea'),
#  ('Iceland', 'Ireland', 'eland'),
#  ('Iceland', 'Netherlands', 'land'),
#  ('Iceland', 'New Zealand', 'land'),
#  ('Iceland', 'Poland', 'land'),
#  ('Iceland', 'Switzerland', 'land'),
#  ('Iceland', 'Thailand', 'land'),
#  ('Iceland', 'Solomon Islands', 'land'),
#  ('Iran, Islamic Rep.', 'Syrian Arab Republic', ' Rep'),
#  ('Iran, Islamic Rep.', 'Yemen, Rep.', ' Rep.'),
#  ('Iran, Islamic Rep.', 'Solomon Islands', ' Isla'),
#  ('Ireland', 'Netherlands', 'land'),
#  ('Ireland', 'New Zealand', 'land'),
#  ('Ireland', 'Poland', 'land'),
#  ('Ireland', 'Switzerland', 'land'),
#  ('Ireland', 'Thailand', 'land'),
#  ('Ireland', 'Solomon Islands', 'land'),
#  ('Kazakhstan', 'Kyrgyzstan', 'stan'),
#  ('Kazakhstan', 'Pakistan', 'stan'),
#  ('Kazakhstan', 'Tajikistan', 'stan'),
#  ('Kazakhstan', 'Afghanistan', 'stan'),
#  ('Kazakhstan', 'Turkmenistan', 'stan'),
#  ('Kazakhstan', 'Uzbekistan', 'stan'),
#  ('South Korea', 'South Africa', 'South '),
#  ('South Korea', 'North Korea', 'th Korea'),
#  ('South Korea', 'South Sudan', 'South '),
#  ('Kyrgyzstan', 'Pakistan', 'stan'),
#  ('Kyrgyzstan', 'Tajikistan', 'stan'),
#  ('Kyrgyzstan', 'Afghanistan', 'stan'),
#  ('Kyrgyzstan', 'Turkmenistan', 'stan'),
#  ('Kyrgyzstan', 'Uzbekistan', 'stan'),
#  ('Liberia', 'Nigeria', 'eria'),
#  ('Lithuania', 'Mauritania', 'ania'),
#  ('Lithuania', 'Romania', 'ania'),
#  ('Lithuania', 'Tanzania', 'ania'),
#  ('Malawi', 'Malaysia', 'Mala'),
#  ('Mauritania', 'Mauritius', 'Maurit'),
#  ('Mauritania', 'Romania', 'ania'),
#  ('Mauritania', 'Tanzania', 'ania'),
#  ('Montenegro', 'Senegal', 'eneg'),
#  ('Mozambique', 'Zambia', 'ambi'),
#  ('Netherlands', 'New Zealand', 'land'),
#  ('Netherlands', 'Poland', 'land'),
#  ('Netherlands', 'Switzerland', 'erland'),
#  ('Netherlands', 'Thailand', 'land'),
#  ('Netherlands', 'Solomon Islands', 'lands'),
#  ('New Zealand', 'Papua New Guinea', 'New '),
#  ('New Zealand', 'Poland', 'land'),
#  ('New Zealand', 'Switzerland', 'land'),
#  ('New Zealand', 'Thailand', 'land'),
#  ('New Zealand', 'Solomon Islands', 'land'),
#  ('Nicaragua', 'Paraguay', 'aragua'),
#  ('Niger', 'Nigeria', 'Niger'),
#  ('North Macedonia', 'North Korea', 'North '),
#  ('Pakistan', 'Tajikistan', 'kistan'),
#  ('Pakistan', 'Afghanistan', 'istan'),
#  ('Pakistan', 'Turkmenistan', 'istan'),
#  ('Pakistan', 'Uzbekistan', 'kistan'),
#  ('Papua New Guinea', 'Equatorial Guinea', ' Guinea'),
#  ('Paraguay', 'Uruguay', 'guay'),
#  ('Philippines', 'Saint Vincent and the Grenadines', 'ines'),
#  ('Poland', 'Switzerland', 'land'),
#  ('Poland', 'Thailand', 'land'),
#  ('Poland', 'Solomon Islands', 'land'),
#  ('Romania', 'Tanzania', 'ania'),
#  ('Russian Federation', 'Syrian Arab Republic', 'ian '),
#  ('Rwanda', 'Uganda', 'anda'),
#  ('Saudi Arabia', 'Syrian Arab Republic', ' Arab'),
#  ('Saudi Arabia', 'United Arab Emirates', ' Arab'),
#  ('Slovakia', 'Slovenia', 'Slov'),
#  ('South Africa', 'South Sudan', 'South '),
#  ('Sudan', 'South Sudan', 'Sudan'),
#  ('Switzerland', 'Thailand', 'land'),
#  ('Switzerland', 'Solomon Islands', 'land'),
#  ('Syrian Arab Republic', 'United Arab Emirates', ' Arab '),
#  ('Syrian Arab Republic', 'Yemen, Rep.', ' Rep'),
#  ('Tajikistan', 'Afghanistan', 'istan'),
#  ('Tajikistan', 'Turkmenistan', 'istan'),
#  ('Tajikistan', 'Uzbekistan', 'kistan'),
#  ('Thailand', 'Solomon Islands', 'land'),
#  ('Trinidad and Tobago', 'Saint Vincent and the Grenadines', ' and '),
#  ('Trinidad and Tobago', 'São Tomé and Príncipe', ' and '),
#  ('United Arab Emirates', 'United Kingdom', 'United '),
#  ('United Arab Emirates', 'United States', 'United '),
#  ('United Kingdom', 'United States', 'United '),
#  ('Afghanistan', 'Turkmenistan', 'nistan'),
#  ('Afghanistan', 'Uzbekistan', 'istan'),
#  ('Grenada', 'Saint Vincent and the Grenadines', 'Grenad'),
#  ('Saint Lucia', 'Saint Vincent and the Grenadines', 'Saint '),
#  ('Saint Vincent and the Grenadines', 'São Tomé and Príncipe', ' and '),
#  ('Turkmenistan', 'Uzbekistan', 'istan')]

# %%
df1[df1.select_dtypes(exclude=['number']).columns.tolist()].head(1)
# Out:
#   iso_code_2 iso_code_3  country data.3 data.4 5bv_cost_of_worker_dismissal  \
# 0         AL        ALB  Albania     23     34                     6.299741
#
#        world_bank_region  \
# 0  Europe & Central Asia
#
#   world_bank_current_income_classification,_1990-present iso3 region
# 0                                                 UM      NaN    NaN

# %%
df1.select_dtypes(exclude=['number']).columns.tolist()
# Out:
# ['iso_code_2',
#  'iso_code_3',
#  'country',
#  'data.3',
#  'data.4',
#  '5bv_cost_of_worker_dismissal',
#  'world_bank_region',
#  'world_bank_current_income_classification,_1990-present',
#  'iso3',
#  'region']

# %%
columns_to_convert = ['data.3', 'data.4', '5bv_cost_of_worker_dismissal']
df1[columns_to_convert] = df1[columns_to_convert].apply(pd.to_numeric, errors='coerce')

# %%
df1 = df1.drop(columns=['iso_code_2',
                        'iso_code_3',
                        # 'world_bank_region',
                        # 'region',
                        'world_bank_current_income_classification,_1990-present',
                        'iso3'])

# %% [markdown]
# ### + FIW

# %%
fiw = fiw.drop(columns='region')
set(df1.columns).intersection(fiw.columns)
# Out:
# {'country', 'year'}

# %%
country_mapping = {
    'Bahamas, The': 'Bahamas',
    "Côte d'Ivoire": "Cote d'Ivoire",
    'Guinea-Bissau': 'Guinea Bissau',
    'South Korea': 'Korea, Rep.',
    'North Korea': 'Korea, Dem. Rep.',
    'United States': 'United States of America',
    'Russia': 'Russian Federation',
    'Sao Tome and Principe': 'São Tomé and Príncipe',
    'The Gambia': 'Gambia, The',
    'Hong Kong SAR, China': 'Hong Kong',
    'Iran, Islamic Rep.': 'Iran',
    'Egypt, Arab Rep.': 'Egypt',
    'Lao PDR': 'Laos',
    'Venezuela, RB': 'Venezuela',
    'Syrian Arab Republic': 'Syria',
    'Türkiye': 'Turkey',
    'Yemen, Rep.': 'Yemen',
    'Congo, Rep.': 'Congo (Brazzaville)',
    'Congo, Dem. Rep.': 'Congo (Kinshasa)',
    'Brunei Darussalam': 'Brunei',
    'Northern Cyprus': 'Cyprus',
    'Czechia': 'Czech Republic',
    'Saint Vincent and the Grenadines': 'St. Vincent and the Grenadines',
    'Saint Lucia': 'St. Lucia'
}

df1['country'] = df1['country'].replace(country_mapping)
fiw['country'] = fiw['country'].replace(country_mapping)

df2 = pd.merge(df1, fiw, on=['country', 'year'], how='outer')

def check_countries(column, min_length=5):
    similar_pairs = []
    for i in range(len(column)):
        for j in range(i + 1, len(column)):
            if column[i] != column[j]:  # Ensure that identical countries are excluded
                seq = difflib.SequenceMatcher(None, column[i], column[j])
                match = seq.find_longest_match(0, len(column[i]), 0, len(column[j]))
                if match.size >= min_length:
                    similar_pairs.append((column[i], column[j], column[i][match.a: match.a + match.size]))
    return similar_pairs

check_countries(df2['country'].unique())
# Out:
# [('Algeria', 'Nigeria', 'geria'),
#  ('Australia', 'Austria', 'Austr'),
#  ('Austria', 'Transnistria', 'stria'),
#  ('Bosnia and Herzegovina', 'Trinidad and Tobago', ' and '),
#  ('Bosnia and Herzegovina', 'St. Vincent and the Grenadines', ' and '),
#  ('Bosnia and Herzegovina', 'São Tomé and Príncipe', ' and '),
#  ('Bosnia and Herzegovina', 'Antigua and Barbuda', 'a and '),
#  ('Bosnia and Herzegovina', 'Serbia and Montenegro', 'ia and '),
#  ('Bosnia and Herzegovina', 'St. Kitts and Nevis', ' and '),
#  ('Central African Republic', 'Czech Republic', ' Republic'),
#  ('Central African Republic', 'Dominican Republic', 'ican Republic'),
#  ('Central African Republic', 'South Africa', ' Africa'),
#  ('Congo (Kinshasa)', 'Congo (Brazzaville)', 'Congo ('),
#  ("Cote d'Ivoire", 'Cote d’Ivoire', 'Cote d'),
#  ('Czech Republic', 'Dominican Republic', ' Republic'),
#  ('Dominican Republic', 'Dominica', 'Dominica'),
#  ('Gambia, The', 'Zambia', 'ambia'),
#  ('Guinea', 'Guinea Bissau', 'Guinea'),
#  ('Guinea', 'Papua New Guinea', 'Guinea'),
#  ('Guinea', 'Equatorial Guinea', 'Guinea'),
#  ('Guinea Bissau', 'Papua New Guinea', 'Guinea'),
#  ('Guinea Bissau', 'Equatorial Guinea', 'Guinea'),
#  ('Iceland', 'Ireland', 'eland'),
#  ('India', 'Indian Kashmir', 'India'),
#  ('Indonesia', 'Micronesia', 'onesia'),
#  ('Israel', 'Israeli Occupied Territories', 'Israel'),
#  ('Israel', 'Israeli-Occupied Territories', 'Israel'),
#  ('Korea, Rep.', 'Korea, Dem. Rep.', 'Korea, '),
#  ('Mauritania', 'Mauritius', 'Maurit'),
#  ('Montenegro', 'Serbia and Montenegro', 'Montenegro'),
#  ('Netherlands', 'Switzerland', 'erland'),
#  ('Netherlands', 'Solomon Islands', 'lands'),
#  ('Netherlands', 'Marshall Islands', 'lands'),
#  ('Nicaragua', 'Paraguay', 'aragua'),
#  ('Niger', 'Nigeria', 'Niger'),
#  ('Pakistan', 'Tajikistan', 'kistan'),
#  ('Pakistan', 'Afghanistan', 'istan'),
#  ('Pakistan', 'Turkmenistan', 'istan'),
#  ('Pakistan', 'Uzbekistan', 'kistan'),
#  ('Pakistan', 'Pakistani Kashmir', 'Pakistan'),
#  ('Papua New Guinea', 'Equatorial Guinea', ' Guinea'),
#  ('Saudi Arabia', 'United Arab Emirates', ' Arab'),
#  ('Serbia', 'Serbia and Montenegro', 'Serbia'),
#  ('Somalia', 'Somaliland', 'Somali'),
#  ('South Africa', 'South Sudan', 'South '),
#  ('South Africa', 'South Ossetia', 'South '),
#  ('Sudan', 'South Sudan', 'Sudan'),
#  ('Tajikistan', 'Afghanistan', 'istan'),
#  ('Tajikistan', 'Turkmenistan', 'istan'),
#  ('Tajikistan', 'Uzbekistan', 'kistan'),
#  ('Tajikistan', 'Pakistani Kashmir', 'kistan'),
#  ('Thailand', 'Somaliland', 'iland'),
#  ('Trinidad and Tobago', 'St. Vincent and the Grenadines', ' and '),
#  ('Trinidad and Tobago', 'São Tomé and Príncipe', ' and '),
#  ('Trinidad and Tobago', 'Antigua and Barbuda', ' and '),
#  ('Trinidad and Tobago', 'Serbia and Montenegro', ' and '),
#  ('Trinidad and Tobago', 'St. Kitts and Nevis', ' and '),
#  ('United Arab Emirates', 'United Kingdom', 'United '),
#  ('United Arab Emirates', 'United States of America', 'United '),
#  ('United Kingdom', 'United States of America', 'United '),
#  ('Afghanistan', 'Turkmenistan', 'nistan'),
#  ('Afghanistan', 'Uzbekistan', 'istan'),
#  ('Afghanistan', 'Pakistani Kashmir', 'istan'),
#  ('Grenada', 'St. Vincent and the Grenadines', 'Grenad'),
#  ('St. Vincent and the Grenadines', 'São Tomé and Príncipe', ' and '),
#  ('St. Vincent and the Grenadines', 'Antigua and Barbuda', ' and '),
#  ('St. Vincent and the Grenadines', 'Serbia and Montenegro', ' and '),
#  ('St. Vincent and the Grenadines', 'St. Kitts and Nevis', ' and '),
#  ('São Tomé and Príncipe', 'Antigua and Barbuda', ' and '),
#  ('São Tomé and Príncipe', 'Serbia and Montenegro', ' and '),
#  ('São Tomé and Príncipe', 'St. Kitts and Nevis', ' and '),
#  ('Solomon Islands', 'Marshall Islands', ' Islands'),
#  ('South Sudan', 'South Ossetia', 'South '),
#  ('Turkmenistan', 'Uzbekistan', 'istan'),
#  ('Turkmenistan', 'Pakistani Kashmir', 'istan'),
#  ('Uzbekistan', 'Pakistani Kashmir', 'kistan'),
#  ('Antigua and Barbuda', 'Serbia and Montenegro', 'a and '),
#  ('Antigua and Barbuda', 'St. Kitts and Nevis', ' and '),
#  ('Eastern Donbas', 'Western Sahara', 'stern '),
#  ('Indian Kashmir', 'Pakistani Kashmir', ' Kashmir'),
#  ('Israeli Occupied Territories',
#   'Israeli-Occupied Territories',
#   'Occupied Territories'),
#  ('Israeli Occupied Territories',
#   'Palestinian Authority Administered Territories',
#   'ed Territories'),
#  ('Israeli Occupied Territories',
#   'Palestinian Authority-Administered Territories',
#   'ed Territories'),
#  ('Israeli-Occupied Territories',
#   'Palestinian Authority Administered Territories',
#   'ed Territories'),
#  ('Israeli-Occupied Territories',
#   'Palestinian Authority-Administered Territories',
#   'ed Territories'),
#  ('Palestinian Authority Administered Territories',
#   'Palestinian Authority-Administered Territories',
#   'Administered Territories'),
#  ('Serbia and Montenegro', 'St. Kitts and Nevis', ' and ')]

# %%
df2[df2.select_dtypes(exclude=['number']).columns.tolist()].head(1)
# Out:
#    country      world_bank_region region c/t? status  pr  cl total
# 0  Albania  Europe & Central Asia    NaN    c     PF  27  39    66

# %%
columns_to_convert = ['pr', 'cl', 'total']
df2[columns_to_convert] = df2[columns_to_convert].apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# ### + IEF

# %%
set(df2.columns).intersection(ief.columns)
# Out:
# {'country', 'year'}

# %%
ief['country'] = ief['country'].str.strip()

country_mapping = {
    'Bahamas': 'The Bahamas',
    'Cabo Verde': 'Cape Verde',
    'Cote d\'Ivoire': "Côte d'Ivoire",
    "Côte d’Ivoire": "Côte d'Ivoire",
    'Guinea Bissau': 'Guinea-Bissau',
    'Korea, Rep.': 'South Korea',
    'Korea, Dem. Rep.': 'North Korea',
    'United States of America': 'United States',
    'Russia': 'Russian Federation',
    'São Tomé and Príncipe': 'São Tomé and Príncipe',
    'The Gambia': 'Gambia, The',
    'Republic of Congo': 'Congo (Brazzaville)',
    'Democratic Republic of Congo': 'Congo (Kinshasa)',
    'Swaziland': 'Eswatini',
    'Macedonia': 'North Macedonia',
    'Burma': 'Myanmar',
    'Bangladesh ': 'Bangladesh',
    'Brunei': 'Brunei Darussalam',
    'Congo (Brazzaville)': 'Republic of Congo',
    'Republic of Congo ': 'Republic of Congo',
    'Costa Rica ': 'Costa Rica',
    "Côte d'Ivoire": 'Cote d’Ivoire',
    "Côte d'Ivoire ": 'Cote d’Ivoire',
    'El Salvador ': 'El Salvador',
    'Guatemala ': 'Guatemala',
    'Kyrgyzstan': 'Kyrgyz Republic',
    'Netherlands': 'The Netherlands',
    'Philippines': 'The Philippines',
    'Slovakia': 'Slovak Republic',
    'St. Lucia': 'Saint Lucia',
    'St. Vincent and the Grenadines': 'Saint Vincent and the Grenadines',
    'Israeli Occupied Territories': 'Israeli-Occupied Territories'
}

df2['country'] = df2['country'].replace(country_mapping)
ief['country'] = ief['country'].replace(country_mapping)

df3 = pd.merge(df2, ief, on=['country', 'year'], how='outer')

def check_countries(column, min_length=5):
    similar_pairs = []
    for i in range(len(column)):
        for j in range(i + 1, len(column)):
            if column[i] != column[j]:  # Ensure that identical countries are excluded
                seq = difflib.SequenceMatcher(None, column[i], column[j])
                match = seq.find_longest_match(0, len(column[i]), 0, len(column[j]))
                if match.size >= min_length:
                    similar_pairs.append((column[i], column[j], column[i][match.a: match.a + match.size]))
    return similar_pairs

check_countries(df3['country'].unique())
# Out:
# [('Algeria', 'Nigeria', 'geria'),
#  ('Australia', 'Austria', 'Austr'),
#  ('Austria', 'Transnistria', 'stria'),
#  ('Bosnia and Herzegovina', 'Trinidad and Tobago', ' and '),
#  ('Bosnia and Herzegovina', 'Saint Vincent and the Grenadines', ' and '),
#  ('Bosnia and Herzegovina', 'São Tomé and Príncipe', ' and '),
#  ('Bosnia and Herzegovina', 'Antigua and Barbuda', 'a and '),
#  ('Bosnia and Herzegovina', 'Serbia and Montenegro', 'ia and '),
#  ('Bosnia and Herzegovina', 'St. Kitts and Nevis', ' and '),
#  ('Central African Republic', 'Republic of Congo', 'Republic'),
#  ('Central African Republic', 'Czech Republic', ' Republic'),
#  ('Central African Republic', 'Dominican Republic', 'ican Republic'),
#  ('Central African Republic', 'Kyrgyz Republic', ' Republic'),
#  ('Central African Republic', 'Slovak Republic', ' Republic'),
#  ('Central African Republic', 'South Africa', ' Africa'),
#  ('Congo (Kinshasa)', 'Republic of Congo', 'Congo'),
#  ('Congo (Kinshasa)', 'Congo (Brazzaville)', 'Congo ('),
#  ('Republic of Congo', 'Czech Republic', 'Republic'),
#  ('Republic of Congo', 'Dominican Republic', 'Republic'),
#  ('Republic of Congo', 'Kyrgyz Republic', 'Republic'),
#  ('Republic of Congo', 'Slovak Republic', 'Republic'),
#  ('Republic of Congo', 'Congo (Brazzaville)', 'Congo'),
#  ("Côte d'Ivoire", 'Cote d’Ivoire', 'Ivoire'),
#  ('Czech Republic', 'Dominican Republic', ' Republic'),
#  ('Czech Republic', 'Kyrgyz Republic', ' Republic'),
#  ('Czech Republic', 'Slovak Republic', ' Republic'),
#  ('Dominican Republic', 'Kyrgyz Republic', ' Republic'),
#  ('Dominican Republic', 'Slovak Republic', ' Republic'),
#  ('Dominican Republic', 'Dominica', 'Dominica'),
#  ('Gambia, The', 'Zambia', 'ambia'),
#  ('Guinea', 'Guinea-Bissau', 'Guinea'),
#  ('Guinea', 'Papua New Guinea', 'Guinea'),
#  ('Guinea', 'Equatorial Guinea', 'Guinea'),
#  ('Guinea-Bissau', 'Papua New Guinea', 'Guinea'),
#  ('Guinea-Bissau', 'Equatorial Guinea', 'Guinea'),
#  ('Iceland', 'Ireland', 'eland'),
#  ('India', 'Indian Kashmir', 'India'),
#  ('Indonesia', 'Micronesia', 'onesia'),
#  ('Israel', 'Israeli-Occupied Territories', 'Israel'),
#  ('South Korea', 'South Africa', 'South '),
#  ('South Korea', 'North Korea', 'th Korea'),
#  ('South Korea', 'South Sudan', 'South '),
#  ('South Korea', 'South Ossetia', 'South '),
#  ('Kyrgyz Republic', 'Slovak Republic', ' Republic'),
#  ('Mauritania', 'Mauritius', 'Maurit'),
#  ('Montenegro', 'Serbia and Montenegro', 'Montenegro'),
#  ('The Netherlands', 'Switzerland', 'erland'),
#  ('The Netherlands', 'Solomon Islands', 'lands'),
#  ('The Netherlands', 'Marshall Islands', 'lands'),
#  ('Nicaragua', 'Paraguay', 'aragua'),
#  ('Niger', 'Nigeria', 'Niger'),
#  ('North Macedonia', 'North Korea', 'North '),
#  ('Pakistan', 'Tajikistan', 'kistan'),
#  ('Pakistan', 'Afghanistan', 'istan'),
#  ('Pakistan', 'Turkmenistan', 'istan'),
#  ('Pakistan', 'Uzbekistan', 'kistan'),
#  ('Pakistan', 'Pakistani Kashmir', 'Pakistan'),
#  ('Papua New Guinea', 'Equatorial Guinea', ' Guinea'),
#  ('Saudi Arabia', 'United Arab Emirates', ' Arab'),
#  ('Serbia', 'Serbia and Montenegro', 'Serbia'),
#  ('Somalia', 'Somaliland', 'Somali'),
#  ('South Africa', 'South Sudan', 'South '),
#  ('South Africa', 'South Ossetia', 'South '),
#  ('Sudan', 'South Sudan', 'Sudan'),
#  ('Tajikistan', 'Afghanistan', 'istan'),
#  ('Tajikistan', 'Turkmenistan', 'istan'),
#  ('Tajikistan', 'Uzbekistan', 'kistan'),
#  ('Tajikistan', 'Pakistani Kashmir', 'kistan'),
#  ('Thailand', 'Somaliland', 'iland'),
#  ('Trinidad and Tobago', 'Saint Vincent and the Grenadines', ' and '),
#  ('Trinidad and Tobago', 'São Tomé and Príncipe', ' and '),
#  ('Trinidad and Tobago', 'Antigua and Barbuda', ' and '),
#  ('Trinidad and Tobago', 'Serbia and Montenegro', ' and '),
#  ('Trinidad and Tobago', 'St. Kitts and Nevis', ' and '),
#  ('United Arab Emirates', 'United Kingdom', 'United '),
#  ('United Arab Emirates', 'United States', 'United '),
#  ('United Kingdom', 'United States', 'United '),
#  ('Afghanistan', 'Turkmenistan', 'nistan'),
#  ('Afghanistan', 'Uzbekistan', 'istan'),
#  ('Afghanistan', 'Pakistani Kashmir', 'istan'),
#  ('Grenada', 'Saint Vincent and the Grenadines', 'Grenad'),
#  ('Saint Lucia', 'Saint Vincent and the Grenadines', 'Saint '),
#  ('Saint Vincent and the Grenadines', 'São Tomé and Príncipe', ' and '),
#  ('Saint Vincent and the Grenadines', 'Antigua and Barbuda', ' and '),
#  ('Saint Vincent and the Grenadines', 'Serbia and Montenegro', ' and '),
#  ('Saint Vincent and the Grenadines', 'St. Kitts and Nevis', ' and '),
#  ('São Tomé and Príncipe', 'Antigua and Barbuda', ' and '),
#  ('São Tomé and Príncipe', 'Serbia and Montenegro', ' and '),
#  ('São Tomé and Príncipe', 'St. Kitts and Nevis', ' and '),
#  ('Solomon Islands', 'Marshall Islands', ' Islands'),
#  ('South Sudan', 'South Ossetia', 'South '),
#  ('Turkmenistan', 'Uzbekistan', 'istan'),
#  ('Turkmenistan', 'Pakistani Kashmir', 'istan'),
#  ('Uzbekistan', 'Pakistani Kashmir', 'kistan'),
#  ('Antigua and Barbuda', 'Serbia and Montenegro', 'a and '),
#  ('Antigua and Barbuda', 'St. Kitts and Nevis', ' and '),
#  ('Eastern Donbas', 'Western Sahara', 'stern '),
#  ('Indian Kashmir', 'Pakistani Kashmir', ' Kashmir'),
#  ('Israeli-Occupied Territories',
#   'Palestinian Authority Administered Territories',
#   'ed Territories'),
#  ('Israeli-Occupied Territories',
#   'Palestinian Authority-Administered Territories',
#   'ed Territories'),
#  ('Palestinian Authority Administered Territories',
#   'Palestinian Authority-Administered Territories',
#   'Administered Territories'),
#  ('Serbia and Montenegro', 'St. Kitts and Nevis', ' and ')]

# %%
df3[df3.select_dtypes(exclude=['number']).columns.tolist()].head(1)
# Out:
#    country      world_bank_region region c/t? status short_name iso_code
# 0  Albania  Europe & Central Asia    NaN    c     PF    Albania       AL

# %%
df3 = df3.drop(columns=['iso_code', 'short_name'])

# %% [markdown]
# ### + P5D

# %%
set(df3.columns).intersection(p5d.columns)
# Out:
# {'country', 'year'}

# %%
country_mapping = {
    'The Bahamas': 'Bahamas',
    'Cote d’Ivoire': "Cote D'Ivoire",
    "Côte d’Ivoire": "Cote D'Ivoire",
    'Republic of Congo': 'Congo Brazzaville',
    'Congo (Kinshasa)': 'Congo Kinshasa',
    'Kyrgyz Republic': 'Kyrgyzstan',
    'South Korea': 'Korea South',
    'North Korea': 'Korea North',
    'The Netherlands': 'Netherlands',
    'The Philippines': 'Philippines',
    'São Tomé and Príncipe': 'Sao Tome and Principe',
    'Timor-Leste': 'Timor Leste',
    'Eswatini': 'Swaziland',
    'USSR': 'Russia',
    'Myanmar': 'Myanmar (Burma)',
    'Vietnam North': 'Vietnam',
    'Vietnam South': 'Vietnam',
    'South Vietnam': 'Vietnam',
    'Yemen North': 'Yemen',
    'Sudan-North': 'Sudan',
    'Bosnia': 'Bosnia and Herzegovina',
    'Congo-Brazzaville': 'Congo Brazzaville',
    'Macedonia': 'North Macedonia',
    'Germany West': 'Germany',
    'Gambia, The': 'Gambia',
    'Yemen South': 'Yemen',
    'Russian Federation': 'Russia'
}

df3['country'] = df3['country'].replace(country_mapping)
p5d['country'] = p5d['country'].replace(country_mapping)

df4 = pd.merge(df3, p5d, on=['country', 'year'], how='outer')

def check_countries(column, min_length=5):
    similar_pairs = []
    for i in range(len(column)):
        for j in range(i + 1, len(column)):
            if column[i] != column[j]:  # Ensure that identical countries are excluded
                seq = difflib.SequenceMatcher(None, column[i], column[j])
                match = seq.find_longest_match(0, len(column[i]), 0, len(column[j]))
                if match.size >= min_length:
                    similar_pairs.append((column[i], column[j], column[i][match.a: match.a + match.size]))
    return similar_pairs

check_countries(df4['country'].unique())
# Out:
# [('Algeria', 'Nigeria', 'geria'),
#  ('Australia', 'Austria', 'Austr'),
#  ('Austria', 'Transnistria', 'stria'),
#  ('Bosnia and Herzegovina', 'Trinidad and Tobago', ' and '),
#  ('Bosnia and Herzegovina', 'Saint Vincent and the Grenadines', ' and '),
#  ('Bosnia and Herzegovina', 'Sao Tome and Principe', ' and '),
#  ('Bosnia and Herzegovina', 'Antigua and Barbuda', 'a and '),
#  ('Bosnia and Herzegovina', 'Serbia and Montenegro', 'ia and '),
#  ('Bosnia and Herzegovina', 'St. Kitts and Nevis', ' and '),
#  ('Central African Republic', 'Czech Republic', ' Republic'),
#  ('Central African Republic', 'Dominican Republic', 'ican Republic'),
#  ('Central African Republic', 'Slovak Republic', ' Republic'),
#  ('Central African Republic', 'South Africa', ' Africa'),
#  ('Congo Kinshasa', 'Congo Brazzaville', 'Congo '),
#  ('Congo Kinshasa', 'Congo (Brazzaville)', 'Congo '),
#  ('Congo Brazzaville', 'Congo (Brazzaville)', 'Brazzaville'),
#  ("Côte d'Ivoire", "Cote D'Ivoire", "'Ivoire"),
#  ('Czech Republic', 'Dominican Republic', ' Republic'),
#  ('Czech Republic', 'Slovak Republic', ' Republic'),
#  ('Czech Republic', 'Czechoslovakia', 'Czech'),
#  ('Dominican Republic', 'Slovak Republic', ' Republic'),
#  ('Dominican Republic', 'Dominica', 'Dominica'),
#  ('Swaziland', 'Thailand', 'iland'),
#  ('Swaziland', 'Somaliland', 'iland'),
#  ('Gambia', 'Zambia', 'ambia'),
#  ('Germany', 'Germany East', 'Germany'),
#  ('Guinea', 'Guinea-Bissau', 'Guinea'),
#  ('Guinea', 'Papua New Guinea', 'Guinea'),
#  ('Guinea', 'Equatorial Guinea', 'Guinea'),
#  ('Guinea-Bissau', 'Papua New Guinea', 'Guinea'),
#  ('Guinea-Bissau', 'Equatorial Guinea', 'Guinea'),
#  ('Iceland', 'Ireland', 'eland'),
#  ('India', 'Indian Kashmir', 'India'),
#  ('Indonesia', 'Micronesia', 'onesia'),
#  ('Israel', 'Israeli-Occupied Territories', 'Israel'),
#  ('Korea South', 'South Africa', 'South'),
#  ('Korea South', 'Korea North', 'Korea '),
#  ('Korea South', 'South Sudan', 'South'),
#  ('Korea South', 'South Ossetia', 'South'),
#  ('Mauritania', 'Mauritius', 'Maurit'),
#  ('Montenegro', 'Serbia and Montenegro', 'Montenegro'),
#  ('Netherlands', 'Switzerland', 'erland'),
#  ('Netherlands', 'Solomon Islands', 'lands'),
#  ('Netherlands', 'Marshall Islands', 'lands'),
#  ('Nicaragua', 'Paraguay', 'aragua'),
#  ('Niger', 'Nigeria', 'Niger'),
#  ('North Macedonia', 'Korea North', 'North'),
#  ('Pakistan', 'Tajikistan', 'kistan'),
#  ('Pakistan', 'Afghanistan', 'istan'),
#  ('Pakistan', 'Turkmenistan', 'istan'),
#  ('Pakistan', 'Uzbekistan', 'kistan'),
#  ('Pakistan', 'Pakistani Kashmir', 'Pakistan'),
#  ('Papua New Guinea', 'Equatorial Guinea', ' Guinea'),
#  ('Saudi Arabia', 'United Arab Emirates', ' Arab'),
#  ('Serbia', 'Serbia and Montenegro', 'Serbia'),
#  ('Slovak Republic', 'Czechoslovakia', 'lovak'),
#  ('Somalia', 'Somaliland', 'Somali'),
#  ('South Africa', 'South Sudan', 'South '),
#  ('South Africa', 'South Ossetia', 'South '),
#  ('Sudan', 'South Sudan', 'Sudan'),
#  ('Tajikistan', 'Afghanistan', 'istan'),
#  ('Tajikistan', 'Turkmenistan', 'istan'),
#  ('Tajikistan', 'Uzbekistan', 'kistan'),
#  ('Tajikistan', 'Pakistani Kashmir', 'kistan'),
#  ('Thailand', 'Somaliland', 'iland'),
#  ('Trinidad and Tobago', 'Saint Vincent and the Grenadines', ' and '),
#  ('Trinidad and Tobago', 'Sao Tome and Principe', ' and '),
#  ('Trinidad and Tobago', 'Antigua and Barbuda', ' and '),
#  ('Trinidad and Tobago', 'Serbia and Montenegro', ' and '),
#  ('Trinidad and Tobago', 'St. Kitts and Nevis', ' and '),
#  ('United Arab Emirates', 'United Kingdom', 'United '),
#  ('United Arab Emirates', 'United States', 'United '),
#  ('United Kingdom', 'United States', 'United '),
#  ('Afghanistan', 'Turkmenistan', 'nistan'),
#  ('Afghanistan', 'Uzbekistan', 'istan'),
#  ('Afghanistan', 'Pakistani Kashmir', 'istan'),
#  ('Grenada', 'Saint Vincent and the Grenadines', 'Grenad'),
#  ('Saint Lucia', 'Saint Vincent and the Grenadines', 'Saint '),
#  ('Saint Vincent and the Grenadines', 'Sao Tome and Principe', ' and '),
#  ('Saint Vincent and the Grenadines', 'Antigua and Barbuda', ' and '),
#  ('Saint Vincent and the Grenadines', 'Serbia and Montenegro', ' and '),
#  ('Saint Vincent and the Grenadines', 'St. Kitts and Nevis', ' and '),
#  ('Sao Tome and Principe', 'Antigua and Barbuda', ' and '),
#  ('Sao Tome and Principe', 'Serbia and Montenegro', ' and '),
#  ('Sao Tome and Principe', 'St. Kitts and Nevis', ' and '),
#  ('Solomon Islands', 'Marshall Islands', ' Islands'),
#  ('South Sudan', 'South Ossetia', 'South '),
#  ('Turkmenistan', 'Uzbekistan', 'istan'),
#  ('Turkmenistan', 'Pakistani Kashmir', 'istan'),
#  ('Uzbekistan', 'Pakistani Kashmir', 'kistan'),
#  ('Antigua and Barbuda', 'Serbia and Montenegro', 'a and '),
#  ('Antigua and Barbuda', 'St. Kitts and Nevis', ' and '),
#  ('Eastern Donbas', 'Western Sahara', 'stern '),
#  ('Indian Kashmir', 'Pakistani Kashmir', ' Kashmir'),
#  ('Israeli-Occupied Territories',
#   'Palestinian Authority Administered Territories',
#   'ed Territories'),
#  ('Israeli-Occupied Territories',
#   'Palestinian Authority-Administered Territories',
#   'ed Territories'),
#  ('Palestinian Authority Administered Territories',
#   'Palestinian Authority-Administered Territories',
#   'Administered Territories'),
#  ('Serbia and Montenegro', 'St. Kitts and Nevis', ' and ')]

# %%
df4[df4.select_dtypes(exclude=['number']).columns.tolist()].head(1)
# Out:
#    country      world_bank_region region c/t? status scode
# 0  Albania  Europe & Central Asia    NaN    c     PF   NaN

# %%
df4 = df4.drop(columns='scode')

# %% [markdown]
# ### + PTS

# %%
set(df4.columns).intersection(pts.columns)
# Out:
# {'country', 'region', 'year'}

# %%
pts = pts.drop(columns='region')

# %%
country_mapping = {
    'Bolivia, Plurinational State of': 'Bolivia',
    "Cote d'Ivoire": "Cote D'Ivoire",
    'Republic of Congo': 'Congo Brazzaville',
    'Congo, the Democratic Republic of the': 'Congo Kinshasa',
    'Iran, Islamic Republic of': 'Iran',
    "Korea, Democratic People's Republic of": 'Korea North',
    'Korea, Republic of': 'Korea South',
    "Lao People's Democratic Republic": 'Laos',
    'Micronesia, Federated States of': 'Micronesia',
    'Moldova, Republic of': 'Moldova',
    'Myanmar': 'Myanmar (Burma)',
    'Sao Tome and Principe': 'Sao Tome and Principe',
    'Syrian Arab Republic': 'Syria',
    'Taiwan, Province of China': 'Taiwan',
    'Tanzania, United Republic of': 'Tanzania',
    'Venezuela, Bolivarian Republic of': 'Venezuela',
    'Viet Nam': 'Vietnam',
    'Western Sahara': 'Western Sahara',
    'Yemen Arab Republic': 'Yemen',
    "Yemen People's Republic": 'Yemen',
    'Yugoslavia, Federal Republic of': 'Yugoslavia',
    'Yugoslavia, Socialist Federal Republic of': 'Yugoslavia',
    'Swaziland': 'Eswatini',
    'Gambia': 'Gambia, The',
    'German Democratic Republic': 'Germany East',
    'German East': 'Germany East',
    'Ivory Coast': "Cote D'Ivoire",
    'UAE': 'United Arab Emirates',
    'Gambia, The': 'Gambia'
}

df4['country'] = df4['country'].replace(country_mapping)
pts['country'] = pts['country'].replace(country_mapping)

df5 = pd.merge(df4, pts, on=['country', 'year'], how='outer')

def check_countries(column, min_length=5):
    similar_pairs = []
    for i in range(len(column)):
        for j in range(i + 1, len(column)):
            if column[i] != column[j]:  # Ensure that identical countries are excluded
                seq = difflib.SequenceMatcher(None, column[i], column[j])
                match = seq.find_longest_match(0, len(column[i]), 0, len(column[j]))
                if match.size >= min_length:
                    similar_pairs.append((column[i], column[j], column[i][match.a: match.a + match.size]))
    return similar_pairs

check_countries(df5['country'].unique())
# Out:
# [('Algeria', 'Nigeria', 'geria'),
#  ('Australia', 'Austria', 'Austr'),
#  ('Austria', 'Transnistria', 'stria'),
#  ('Bosnia and Herzegovina', 'Trinidad and Tobago', ' and '),
#  ('Bosnia and Herzegovina', 'Saint Vincent and the Grenadines', ' and '),
#  ('Bosnia and Herzegovina', 'Sao Tome and Principe', ' and '),
#  ('Bosnia and Herzegovina', 'Antigua and Barbuda', 'a and '),
#  ('Bosnia and Herzegovina', 'Serbia and Montenegro', 'ia and '),
#  ('Bosnia and Herzegovina', 'St. Kitts and Nevis', ' and '),
#  ('Bosnia and Herzegovina', 'Saint Kitts and Nevis', ' and '),
#  ('Cape Verde', 'Cabo Verde', ' Verde'),
#  ('Central African Republic', 'Czech Republic', ' Republic'),
#  ('Central African Republic', 'Dominican Republic', 'ican Republic'),
#  ('Central African Republic', 'Slovak Republic', ' Republic'),
#  ('Central African Republic', 'South Africa', ' Africa'),
#  ('Central African Republic', 'German Federal Republic', ' Republic'),
#  ('Congo Kinshasa', 'Congo Brazzaville', 'Congo '),
#  ('Congo Kinshasa', 'Congo (Brazzaville)', 'Congo '),
#  ('Congo Kinshasa', 'Congo', 'Congo'),
#  ('Congo Brazzaville', 'Congo (Brazzaville)', 'Brazzaville'),
#  ('Congo Brazzaville', 'Congo', 'Congo'),
#  ("Côte d'Ivoire", "Cote D'Ivoire", "'Ivoire"),
#  ('Czech Republic', 'Dominican Republic', ' Republic'),
#  ('Czech Republic', 'Slovak Republic', ' Republic'),
#  ('Czech Republic', 'Czechoslovakia', 'Czech'),
#  ('Czech Republic', 'German Federal Republic', ' Republic'),
#  ('Dominican Republic', 'Slovak Republic', ' Republic'),
#  ('Dominican Republic', 'Dominica', 'Dominica'),
#  ('Dominican Republic', 'German Federal Republic', ' Republic'),
#  ('Gambia', 'Zambia', 'ambia'),
#  ('Germany', 'Germany East', 'Germany'),
#  ('Germany', 'German Federal Republic', 'German'),
#  ('Guinea', 'Guinea-Bissau', 'Guinea'),
#  ('Guinea', 'Papua New Guinea', 'Guinea'),
#  ('Guinea', 'Equatorial Guinea', 'Guinea'),
#  ('Guinea-Bissau', 'Papua New Guinea', 'Guinea'),
#  ('Guinea-Bissau', 'Equatorial Guinea', 'Guinea'),
#  ('Iceland', 'Ireland', 'eland'),
#  ('India', 'Indian Kashmir', 'India'),
#  ('Indonesia', 'Micronesia', 'onesia'),
#  ('Israel', 'Israeli-Occupied Territories', 'Israel'),
#  ('Israel', 'Israel in Occupied Territories', 'Israel'),
#  ('Israel', 'Israel in pre-1967 borders', 'Israel'),
#  ('Korea South', 'South Africa', 'South'),
#  ('Korea South', 'Korea North', 'Korea '),
#  ('Korea South', 'South Sudan', 'South'),
#  ('Korea South', 'South Ossetia', 'South'),
#  ('Mauritania', 'Mauritius', 'Maurit'),
#  ('Montenegro', 'Serbia and Montenegro', 'Montenegro'),
#  ('Netherlands', 'Switzerland', 'erland'),
#  ('Netherlands', 'Solomon Islands', 'lands'),
#  ('Netherlands', 'Marshall Islands', 'lands'),
#  ('Nicaragua', 'Paraguay', 'aragua'),
#  ('Niger', 'Nigeria', 'Niger'),
#  ('North Macedonia', 'Korea North', 'North'),
#  ('Pakistan', 'Tajikistan', 'kistan'),
#  ('Pakistan', 'Afghanistan', 'istan'),
#  ('Pakistan', 'Turkmenistan', 'istan'),
#  ('Pakistan', 'Uzbekistan', 'kistan'),
#  ('Pakistan', 'Pakistani Kashmir', 'Pakistan'),
#  ('Papua New Guinea', 'Equatorial Guinea', ' Guinea'),
#  ('Russia', 'Russian Federation', 'Russia'),
#  ('Russia', 'Russia-Occupied Areas (Ukraine)', 'Russia'),
#  ('Saudi Arabia', 'United Arab Emirates', ' Arab'),
#  ('Serbia', 'Serbia and Montenegro', 'Serbia'),
#  ('Slovak Republic', 'Czechoslovakia', 'lovak'),
#  ('Slovak Republic', 'German Federal Republic', ' Republic'),
#  ('Slovak Republic', 'Slovakia', 'Slovak'),
#  ('Somalia', 'Somaliland', 'Somali'),
#  ('South Africa', 'South Sudan', 'South '),
#  ('South Africa', 'South Ossetia', 'South '),
#  ('Sudan', 'South Sudan', 'Sudan'),
#  ('Tajikistan', 'Afghanistan', 'istan'),
#  ('Tajikistan', 'Turkmenistan', 'istan'),
#  ('Tajikistan', 'Uzbekistan', 'kistan'),
#  ('Tajikistan', 'Pakistani Kashmir', 'kistan'),
#  ('Thailand', 'Somaliland', 'iland'),
#  ('Timor Leste', 'Timor-Leste', 'Timor'),
#  ('Trinidad and Tobago', 'Saint Vincent and the Grenadines', ' and '),
#  ('Trinidad and Tobago', 'Sao Tome and Principe', ' and '),
#  ('Trinidad and Tobago', 'Antigua and Barbuda', ' and '),
#  ('Trinidad and Tobago', 'Serbia and Montenegro', ' and '),
#  ('Trinidad and Tobago', 'St. Kitts and Nevis', ' and '),
#  ('Trinidad and Tobago', 'Saint Kitts and Nevis', ' and '),
#  ('Ukraine', 'Russia-Occupied Areas (Ukraine)', 'Ukraine'),
#  ('United Arab Emirates', 'United Kingdom', 'United '),
#  ('United Arab Emirates', 'United States', 'United '),
#  ('United Arab Emirates', 'Russia-Occupied Areas (Ukraine)', 'ed Ar'),
#  ('United Kingdom', 'United States', 'United '),
#  ('United States', 'Palestine, State of', ' State'),
#  ('Afghanistan', 'Turkmenistan', 'nistan'),
#  ('Afghanistan', 'Uzbekistan', 'istan'),
#  ('Afghanistan', 'Pakistani Kashmir', 'istan'),
#  ('Grenada', 'Saint Vincent and the Grenadines', 'Grenad'),
#  ('Saint Lucia', 'Saint Vincent and the Grenadines', 'Saint '),
#  ('Saint Lucia', 'Saint Kitts and Nevis', 'Saint '),
#  ('Saint Vincent and the Grenadines', 'Sao Tome and Principe', ' and '),
#  ('Saint Vincent and the Grenadines', 'Antigua and Barbuda', ' and '),
#  ('Saint Vincent and the Grenadines', 'Serbia and Montenegro', ' and '),
#  ('Saint Vincent and the Grenadines', 'St. Kitts and Nevis', ' and '),
#  ('Saint Vincent and the Grenadines', 'Saint Kitts and Nevis', 'Saint '),
#  ('Sao Tome and Principe', 'Antigua and Barbuda', ' and '),
#  ('Sao Tome and Principe', 'Serbia and Montenegro', ' and '),
#  ('Sao Tome and Principe', 'St. Kitts and Nevis', ' and '),
#  ('Sao Tome and Principe', 'Saint Kitts and Nevis', ' and '),
#  ('Solomon Islands', 'Marshall Islands', ' Islands'),
#  ('South Sudan', 'South Ossetia', 'South '),
#  ('Turkmenistan', 'Uzbekistan', 'istan'),
#  ('Turkmenistan', 'Pakistani Kashmir', 'istan'),
#  ('Uzbekistan', 'Pakistani Kashmir', 'kistan'),
#  ('Antigua and Barbuda', 'Serbia and Montenegro', 'a and '),
#  ('Antigua and Barbuda', 'St. Kitts and Nevis', ' and '),
#  ('Antigua and Barbuda', 'Saint Kitts and Nevis', ' and '),
#  ('Eastern Donbas', 'Western Sahara', 'stern '),
#  ('Gaza Strip', 'Gaza (Hamas)', 'Gaza '),
#  ('Indian Kashmir', 'Pakistani Kashmir', ' Kashmir'),
#  ('Israeli-Occupied Territories',
#   'Palestinian Authority Administered Territories',
#   'ed Territories'),
#  ('Israeli-Occupied Territories',
#   'Palestinian Authority-Administered Territories',
#   'ed Territories'),
#  ('Israeli-Occupied Territories',
#   'Israel in Occupied Territories',
#   'Occupied Territories'),
#  ('Israeli-Occupied Territories', 'Israel in pre-1967 borders', 'Israel'),
#  ('Israeli-Occupied Territories',
#   'Russia-Occupied Areas (Ukraine)',
#   '-Occupied '),
#  ('Palestinian Authority Administered Territories',
#   'Palestinian Authority-Administered Territories',
#   'Administered Territories'),
#  ('Palestinian Authority Administered Territories',
#   'Israel in Occupied Territories',
#   'ed Territories'),
#  ('Palestinian Authority Administered Territories',
#   'Palestine, State of',
#   'Palestin'),
#  ('Palestinian Authority-Administered Territories',
#   'Israel in Occupied Territories',
#   'ed Territories'),
#  ('Palestinian Authority-Administered Territories',
#   'Palestine, State of',
#   'Palestin'),
#  ('Serbia and Montenegro', 'St. Kitts and Nevis', ' and '),
#  ('Serbia and Montenegro', 'Saint Kitts and Nevis', ' and '),
#  ('St. Kitts and Nevis', 'Saint Kitts and Nevis', ' Kitts and Nevis'),
#  ('Congo (Brazzaville)', 'Congo', 'Congo'),
#  ('Czechoslovakia', 'Slovakia', 'lovakia'),
#  ('Germany East', 'German Federal Republic', 'German'),
#  ('European Union', 'Soviet Union', ' Union'),
#  ('German Federal Republic', 'Russian Federation', 'an Federa'),
#  ('Israel in Occupied Territories',
#   'Israel in pre-1967 borders',
#   'Israel in '),
#  ('Israel in Occupied Territories',
#   'Russia-Occupied Areas (Ukraine)',
#   'Occupied '),
#  ('Russian Federation', 'Russia-Occupied Areas (Ukraine)', 'Russia')]

# %%
df5[df5.select_dtypes(exclude=['number']).columns.tolist()].head(1)
# Out:
#    country      world_bank_region region c/t? status country_old cow_code_a  \
# 0  Albania  Europe & Central Asia    NaN    c     PF     Albania        ALB
#
#   wordbank_code_a
# 0             ALB

# %%
df5 = df5.drop(columns=['cow_code_a', 'country_old', 'wordbank_code_a'])

# %% [markdown]
# ### + WGI

# %%
set(df5.columns).intersection(wgi.columns)
# Out:
# {'country', 'year'}

# %%
wgi['year'] = wgi['year'].astype(int)

# %%
country_mapping = {
    'Bahamas': 'Bahamas, The',
    "Cote D'Ivoire": "Côte d'Ivoire",
    'Cape Verde': 'Cabo Verde',
    'Congo Kinshasa': 'Congo, Dem. Rep.',
    'Congo Brazzaville': 'Congo, Rep.',
    'Korea South': 'Korea, Rep.',
    'Korea North': 'Korea, Dem. Rep.',
    'Laos': 'Lao PDR',
    'Micronesia': 'Micronesia, Fed. Sts.',
    'Myanmar (Burma)': 'Myanmar',
    'Sao Tome and Principe': 'São Tomé and Principe',
    'Swaziland': 'Eswatini',
    'Ivory Coast': "Côte d'Ivoire",
    'UAE': 'United Arab Emirates',
    'Taiwan': 'Taiwan, China',
    'Russia': 'Russian Federation',
    'Yemen': 'Yemen, Rep.',
    'Venezuela': 'Venezuela, RB',
    'Türkiye': 'Turkey',
    'Egypt': 'Egypt, Arab Rep.',
    'Gambia': 'Gambia, The',
    'Hong Kong': 'Hong Kong SAR, China',
    'Kyrgyzstan': 'Kyrgyz Republic',
    'Syria': 'Syrian Arab Republic',
    'Saint Lucia': 'St. Lucia',
    'Timor Leste': 'Timor-Leste'
}

df5['country'] = df5['country'].replace(country_mapping)
wgi['country'] = wgi['country'].replace(country_mapping)

df6 = pd.merge(df5, wgi, on=['country', 'year'], how='outer')

def check_countries(column, min_length=5):
    similar_pairs = []
    for i in range(len(column)):
        for j in range(i + 1, len(column)):
            if column[i] != column[j]:  # Ensure that identical countries are excluded
                seq = difflib.SequenceMatcher(None, column[i], column[j])
                match = seq.find_longest_match(0, len(column[i]), 0, len(column[j]))
                if match.size >= min_length:
                    similar_pairs.append((column[i], column[j], column[i][match.a: match.a + match.size]))
    return similar_pairs

check_countries(df6['country'].unique())
# Out:
# [('Algeria', 'Nigeria', 'geria'),
#  ('Australia', 'Austria', 'Austr'),
#  ('Austria', 'Transnistria', 'stria'),
#  ('Bahamas, The', 'Gambia, The', ', The'),
#  ('Bosnia and Herzegovina', 'Trinidad and Tobago', ' and '),
#  ('Bosnia and Herzegovina', 'Saint Vincent and the Grenadines', ' and '),
#  ('Bosnia and Herzegovina', 'São Tomé and Principe', ' and '),
#  ('Bosnia and Herzegovina', 'Antigua and Barbuda', 'a and '),
#  ('Bosnia and Herzegovina', 'Serbia and Montenegro', 'ia and '),
#  ('Bosnia and Herzegovina', 'St. Kitts and Nevis', ' and '),
#  ('Bosnia and Herzegovina', 'Saint Kitts and Nevis', ' and '),
#  ('Bosnia and Herzegovina', 'St. Vincent and the Grenadines', ' and '),
#  ('Bosnia and Herzegovina', 'West Bank and Gaza', ' and '),
#  ('Central African Republic', 'Czech Republic', ' Republic'),
#  ('Central African Republic', 'Dominican Republic', 'ican Republic'),
#  ('Central African Republic', 'Kyrgyz Republic', ' Republic'),
#  ('Central African Republic', 'Slovak Republic', ' Republic'),
#  ('Central African Republic', 'South Africa', ' Africa'),
#  ('Central African Republic', 'Syrian Arab Republic', ' Republic'),
#  ('Central African Republic', 'German Federal Republic', ' Republic'),
#  ('Central African Republic', 'American Samoa', 'rican '),
#  ('China', 'Hong Kong SAR, China', 'China'),
#  ('China', 'Taiwan, China', 'China'),
#  ('China', 'Macao SAR, China', 'China'),
#  ('Congo, Dem. Rep.', 'Congo, Rep.', 'Congo, '),
#  ('Congo, Dem. Rep.', 'Egypt, Arab Rep.', ' Rep.'),
#  ('Congo, Dem. Rep.', 'Korea, Rep.', ' Rep.'),
#  ('Congo, Dem. Rep.', 'Yemen, Rep.', ' Rep.'),
#  ('Congo, Dem. Rep.', 'Korea, Dem. Rep.', ', Dem. Rep.'),
#  ('Congo, Dem. Rep.', 'Congo (Brazzaville)', 'Congo'),
#  ('Congo, Dem. Rep.', 'Congo', 'Congo'),
#  ('Congo, Dem. Rep.', 'Iran, Islamic Rep.', ' Rep.'),
#  ('Congo, Rep.', 'Egypt, Arab Rep.', ' Rep.'),
#  ('Congo, Rep.', 'Korea, Rep.', ', Rep.'),
#  ('Congo, Rep.', 'Yemen, Rep.', ', Rep.'),
#  ('Congo, Rep.', 'Korea, Dem. Rep.', ' Rep.'),
#  ('Congo, Rep.', 'Congo (Brazzaville)', 'Congo'),
#  ('Congo, Rep.', 'Congo', 'Congo'),
#  ('Congo, Rep.', 'Iran, Islamic Rep.', ' Rep.'),
#  ('Czech Republic', 'Dominican Republic', ' Republic'),
#  ('Czech Republic', 'Kyrgyz Republic', ' Republic'),
#  ('Czech Republic', 'Slovak Republic', ' Republic'),
#  ('Czech Republic', 'Syrian Arab Republic', ' Republic'),
#  ('Czech Republic', 'Czechoslovakia', 'Czech'),
#  ('Czech Republic', 'German Federal Republic', ' Republic'),
#  ('Dominican Republic', 'Kyrgyz Republic', ' Republic'),
#  ('Dominican Republic', 'Slovak Republic', ' Republic'),
#  ('Dominican Republic', 'Syrian Arab Republic', ' Republic'),
#  ('Dominican Republic', 'Dominica', 'Dominica'),
#  ('Dominican Republic', 'German Federal Republic', ' Republic'),
#  ('Dominican Republic', 'American Samoa', 'ican '),
#  ('Egypt, Arab Rep.', 'Korea, Rep.', ' Rep.'),
#  ('Egypt, Arab Rep.', 'Saudi Arabia', ' Arab'),
#  ('Egypt, Arab Rep.', 'Syrian Arab Republic', ' Arab Rep'),
#  ('Egypt, Arab Rep.', 'United Arab Emirates', ' Arab '),
#  ('Egypt, Arab Rep.', 'Yemen, Rep.', ' Rep.'),
#  ('Egypt, Arab Rep.', 'Korea, Dem. Rep.', ' Rep.'),
#  ('Egypt, Arab Rep.', 'Iran, Islamic Rep.', ' Rep.'),
#  ('Finland', 'Greenland', 'nland'),
#  ('Gambia, The', 'Zambia', 'ambia'),
#  ('Germany', 'Germany East', 'Germany'),
#  ('Germany', 'German Federal Republic', 'German'),
#  ('Guinea', 'Guinea-Bissau', 'Guinea'),
#  ('Guinea', 'Papua New Guinea', 'Guinea'),
#  ('Guinea', 'Equatorial Guinea', 'Guinea'),
#  ('Guinea-Bissau', 'Papua New Guinea', 'Guinea'),
#  ('Guinea-Bissau', 'Equatorial Guinea', 'Guinea'),
#  ('Hong Kong SAR, China', 'Taiwan, China', ', China'),
#  ('Hong Kong SAR, China', 'Macao SAR, China', ' SAR, China'),
#  ('Iceland', 'Ireland', 'eland'),
#  ('India', 'Indian Kashmir', 'India'),
#  ('Indonesia', 'Micronesia, Fed. Sts.', 'onesia'),
#  ('Israel', 'Israeli-Occupied Territories', 'Israel'),
#  ('Israel', 'Israel in Occupied Territories', 'Israel'),
#  ('Israel', 'Israel in pre-1967 borders', 'Israel'),
#  ('Korea, Rep.', 'Yemen, Rep.', ', Rep.'),
#  ('Korea, Rep.', 'Korea, Dem. Rep.', 'Korea, '),
#  ('Korea, Rep.', 'Iran, Islamic Rep.', ' Rep.'),
#  ('Kyrgyz Republic', 'Slovak Republic', ' Republic'),
#  ('Kyrgyz Republic', 'Syrian Arab Republic', ' Republic'),
#  ('Kyrgyz Republic', 'German Federal Republic', ' Republic'),
#  ('Mauritania', 'Mauritius', 'Maurit'),
#  ('Montenegro', 'Serbia and Montenegro', 'Montenegro'),
#  ('Netherlands', 'Switzerland', 'erland'),
#  ('Netherlands', 'Solomon Islands', 'lands'),
#  ('Netherlands', 'Marshall Islands', 'lands'),
#  ('Netherlands', 'Cayman Islands', 'lands'),
#  ('Netherlands', 'Cook Islands', 'lands'),
#  ('Netherlands', 'Jersey, Channel Islands', 'lands'),
#  ('Netherlands', 'Netherlands Antilles (former)', 'Netherlands'),
#  ('Netherlands', 'Virgin Islands (U.S.)', 'lands'),
#  ('Nicaragua', 'Paraguay', 'aragua'),
#  ('Niger', 'Nigeria', 'Niger'),
#  ('Pakistan', 'Tajikistan', 'kistan'),
#  ('Pakistan', 'Afghanistan', 'istan'),
#  ('Pakistan', 'Turkmenistan', 'istan'),
#  ('Pakistan', 'Uzbekistan', 'kistan'),
#  ('Pakistan', 'Pakistani Kashmir', 'Pakistan'),
#  ('Papua New Guinea', 'Equatorial Guinea', ' Guinea'),
#  ('Russian Federation', 'German Federal Republic', 'an Federa'),
#  ('Russian Federation', 'Russia-Occupied Areas (Ukraine)', 'Russia'),
#  ('Saudi Arabia', 'Syrian Arab Republic', ' Arab'),
#  ('Saudi Arabia', 'United Arab Emirates', ' Arab'),
#  ('Serbia', 'Serbia and Montenegro', 'Serbia'),
#  ('Slovak Republic', 'Syrian Arab Republic', ' Republic'),
#  ('Slovak Republic', 'Czechoslovakia', 'lovak'),
#  ('Slovak Republic', 'German Federal Republic', ' Republic'),
#  ('Slovak Republic', 'Slovakia', 'Slovak'),
#  ('Somalia', 'Somaliland', 'Somali'),
#  ('South Africa', 'South Sudan', 'South '),
#  ('South Africa', 'South Ossetia', 'South '),
#  ('Sudan', 'South Sudan', 'Sudan'),
#  ('Switzerland', 'Netherlands Antilles (former)', 'erland'),
#  ('Syrian Arab Republic', 'United Arab Emirates', ' Arab '),
#  ('Syrian Arab Republic',
#   'Palestinian Authority Administered Territories',
#   'ian A'),
#  ('Syrian Arab Republic',
#   'Palestinian Authority-Administered Territories',
#   'ian A'),
#  ('Syrian Arab Republic', 'German Federal Republic', ' Republic'),
#  ('Taiwan, China', 'Macao SAR, China', ', China'),
#  ('Tajikistan', 'Afghanistan', 'istan'),
#  ('Tajikistan', 'Turkmenistan', 'istan'),
#  ('Tajikistan', 'Uzbekistan', 'kistan'),
#  ('Tajikistan', 'Pakistani Kashmir', 'kistan'),
#  ('Thailand', 'Somaliland', 'iland'),
#  ('Trinidad and Tobago', 'Saint Vincent and the Grenadines', ' and '),
#  ('Trinidad and Tobago', 'São Tomé and Principe', ' and '),
#  ('Trinidad and Tobago', 'Antigua and Barbuda', ' and '),
#  ('Trinidad and Tobago', 'Serbia and Montenegro', ' and '),
#  ('Trinidad and Tobago', 'St. Kitts and Nevis', ' and '),
#  ('Trinidad and Tobago', 'Saint Kitts and Nevis', ' and '),
#  ('Trinidad and Tobago', 'St. Vincent and the Grenadines', ' and '),
#  ('Trinidad and Tobago', 'West Bank and Gaza', ' and '),
#  ('Ukraine', 'Russia-Occupied Areas (Ukraine)', 'Ukraine'),
#  ('United Arab Emirates', 'United Kingdom', 'United '),
#  ('United Arab Emirates', 'United States', 'United '),
#  ('United Arab Emirates', 'Russia-Occupied Areas (Ukraine)', 'ed Ar'),
#  ('United Kingdom', 'United States', 'United '),
#  ('United States', 'Palestine, State of', ' State'),
#  ('Yemen, Rep.', 'Korea, Dem. Rep.', ' Rep.'),
#  ('Yemen, Rep.', 'Iran, Islamic Rep.', ' Rep.'),
#  ('Afghanistan', 'Turkmenistan', 'nistan'),
#  ('Afghanistan', 'Uzbekistan', 'istan'),
#  ('Afghanistan', 'Pakistani Kashmir', 'istan'),
#  ('Grenada', 'Saint Vincent and the Grenadines', 'Grenad'),
#  ('Grenada', 'St. Vincent and the Grenadines', 'Grenad'),
#  ('Korea, Dem. Rep.', 'Iran, Islamic Rep.', ' Rep.'),
#  ('Saint Vincent and the Grenadines', 'São Tomé and Principe', ' and '),
#  ('Saint Vincent and the Grenadines', 'Antigua and Barbuda', ' and '),
#  ('Saint Vincent and the Grenadines', 'Serbia and Montenegro', ' and '),
#  ('Saint Vincent and the Grenadines', 'St. Kitts and Nevis', ' and '),
#  ('Saint Vincent and the Grenadines', 'Saint Kitts and Nevis', 'Saint '),
#  ('Saint Vincent and the Grenadines',
#   'St. Vincent and the Grenadines',
#   ' Vincent and the Grenadines'),
#  ('Saint Vincent and the Grenadines', 'West Bank and Gaza', ' and '),
#  ('São Tomé and Principe', 'Antigua and Barbuda', ' and '),
#  ('São Tomé and Principe', 'Serbia and Montenegro', ' and '),
#  ('São Tomé and Principe', 'St. Kitts and Nevis', ' and '),
#  ('São Tomé and Principe', 'Saint Kitts and Nevis', ' and '),
#  ('São Tomé and Principe', 'St. Vincent and the Grenadines', ' and '),
#  ('São Tomé and Principe', 'West Bank and Gaza', ' and '),
#  ('Solomon Islands', 'Marshall Islands', ' Islands'),
#  ('Solomon Islands', 'Cayman Islands', 'n Islands'),
#  ('Solomon Islands', 'Cook Islands', ' Islands'),
#  ('Solomon Islands', 'Iran, Islamic Rep.', ' Isla'),
#  ('Solomon Islands', 'Jersey, Channel Islands', ' Islands'),
#  ('Solomon Islands', 'Netherlands Antilles (former)', 'lands'),
#  ('Solomon Islands', 'Virgin Islands (U.S.)', 'n Islands'),
#  ('South Sudan', 'South Ossetia', 'South '),
#  ('Turkmenistan', 'Uzbekistan', 'istan'),
#  ('Turkmenistan', 'Pakistani Kashmir', 'istan'),
#  ('Uzbekistan', 'Pakistani Kashmir', 'kistan'),
#  ('Antigua and Barbuda', 'Serbia and Montenegro', 'a and '),
#  ('Antigua and Barbuda', 'St. Kitts and Nevis', ' and '),
#  ('Antigua and Barbuda', 'Saint Kitts and Nevis', ' and '),
#  ('Antigua and Barbuda', 'St. Vincent and the Grenadines', ' and '),
#  ('Antigua and Barbuda', 'West Bank and Gaza', ' and '),
#  ('Eastern Donbas', 'Western Sahara', 'stern '),
#  ('Gaza Strip', 'Gaza (Hamas)', 'Gaza '),
#  ('Indian Kashmir', 'Pakistani Kashmir', ' Kashmir'),
#  ('Israeli-Occupied Territories',
#   'Palestinian Authority Administered Territories',
#   'ed Territories'),
#  ('Israeli-Occupied Territories',
#   'Palestinian Authority-Administered Territories',
#   'ed Territories'),
#  ('Israeli-Occupied Territories',
#   'Israel in Occupied Territories',
#   'Occupied Territories'),
#  ('Israeli-Occupied Territories', 'Israel in pre-1967 borders', 'Israel'),
#  ('Israeli-Occupied Territories',
#   'Russia-Occupied Areas (Ukraine)',
#   '-Occupied '),
#  ('Marshall Islands', 'Cayman Islands', ' Islands'),
#  ('Marshall Islands', 'Cook Islands', ' Islands'),
#  ('Marshall Islands', 'Iran, Islamic Rep.', ' Isla'),
#  ('Marshall Islands', 'Jersey, Channel Islands', 'l Islands'),
#  ('Marshall Islands', 'Netherlands Antilles (former)', 'lands'),
#  ('Marshall Islands', 'Virgin Islands (U.S.)', ' Islands'),
#  ('Palestinian Authority Administered Territories',
#   'Palestinian Authority-Administered Territories',
#   'Administered Territories'),
#  ('Palestinian Authority Administered Territories',
#   'Israel in Occupied Territories',
#   'ed Territories'),
#  ('Palestinian Authority Administered Territories',
#   'Palestine, State of',
#   'Palestin'),
#  ('Palestinian Authority-Administered Territories',
#   'Israel in Occupied Territories',
#   'ed Territories'),
#  ('Palestinian Authority-Administered Territories',
#   'Palestine, State of',
#   'Palestin'),
#  ('Samoa', 'American Samoa', 'Samoa'),
#  ('Serbia and Montenegro', 'St. Kitts and Nevis', ' and '),
#  ('Serbia and Montenegro', 'Saint Kitts and Nevis', ' and '),
#  ('Serbia and Montenegro', 'St. Vincent and the Grenadines', ' and '),
#  ('Serbia and Montenegro', 'West Bank and Gaza', ' and '),
#  ('St. Kitts and Nevis', 'Saint Kitts and Nevis', ' Kitts and Nevis'),
#  ('St. Kitts and Nevis', 'St. Vincent and the Grenadines', ' and '),
#  ('St. Kitts and Nevis', 'West Bank and Gaza', ' and '),
#  ('West Bank', 'West Bank and Gaza', 'West Bank'),
#  ('Congo (Brazzaville)', 'Congo', 'Congo'),
#  ('Czechoslovakia', 'Slovakia', 'lovakia'),
#  ('Germany East', 'German Federal Republic', 'German'),
#  ('European Union', 'Soviet Union', ' Union'),
#  ('Israel in Occupied Territories',
#   'Israel in pre-1967 borders',
#   'Israel in '),
#  ('Israel in Occupied Territories',
#   'Russia-Occupied Areas (Ukraine)',
#   'Occupied '),
#  ('Saint Kitts and Nevis', 'St. Vincent and the Grenadines', ' and '),
#  ('Saint Kitts and Nevis', 'West Bank and Gaza', ' and '),
#  ('Cayman Islands', 'Cook Islands', ' Islands'),
#  ('Cayman Islands', 'Iran, Islamic Rep.', ' Isla'),
#  ('Cayman Islands', 'Jersey, Channel Islands', ' Islands'),
#  ('Cayman Islands', 'Netherlands Antilles (former)', 'lands'),
#  ('Cayman Islands', 'Virgin Islands (U.S.)', 'n Islands'),
#  ('Cook Islands', 'Iran, Islamic Rep.', ' Isla'),
#  ('Cook Islands', 'Jersey, Channel Islands', ' Islands'),
#  ('Cook Islands', 'Netherlands Antilles (former)', 'lands'),
#  ('Cook Islands', 'Virgin Islands (U.S.)', ' Islands'),
#  ('Iran, Islamic Rep.', 'Jersey, Channel Islands', ' Isla'),
#  ('Iran, Islamic Rep.', 'Virgin Islands (U.S.)', ' Isla'),
#  ('Jersey, Channel Islands', 'Netherlands Antilles (former)', 'lands'),
#  ('Jersey, Channel Islands', 'Virgin Islands (U.S.)', ' Islands'),
#  ('Netherlands Antilles (former)', 'Virgin Islands (U.S.)', 'lands '),
#  ('St. Vincent and the Grenadines', 'West Bank and Gaza', ' and ')]

# %%
df6[df6.select_dtypes(exclude=['number']).columns.tolist()].head(1)
# Out:
#    country      world_bank_region region c/t? status code
# 0  Albania  Europe & Central Asia    NaN    c     PF  ALB

# %%
df6 = df6.drop(columns='code')

# %% [markdown]
# ### + WB

# %%
set(df6.columns).intersection(wb.columns)
# Out:
# {'country', 'year'}

# %%
country_groups = [
    '(UN) Africa', '(UN) Asia', '(UN) Europe', '(UN) Latin America and the Caribbean', 
    '(UN) North America', '(SDG) Central/Southern Asia', '(SDG) Eastern/South Eastern Asia', 
    '(SDG) Europe', '(SDG) Latin America & the Caribbean', '(SDG) Northern America', 
    '(SDG) Sub-Saharan Africa', '(SDG) Western Asia/Northern Africa',
    'Africa Eastern and Southern', 'Africa Western and Central',
    'Association of Southeast Asian Nations (ASEAN-5)',
    'Central Europe and the Baltics', 'Caribbean small states',
    'East Asia & Pacific (excluding high income)', 'East Asia & Pacific',
    'Europe & Central Asia (excluding high income)', 'Europe & Central Asia',
    'Emerging and Developing Europe', 'Euro area',
    'Europe & Central Asia (IDA & IBRD countries)',
    'Latin America & Caribbean (excluding high income)', 'Latin America & Caribbean',
    'Least developed countries: UN classification', 'Middle East & North Africa',
    'Middle East & Central Asia', 'Pacific island small states',
    'South Asia (IDA & IBRD)', 'Small states',
    'Sub-Saharan Africa (excluding high income)',
    'Sub-Saharan Africa (IDA & IBRD countries)',
    'Upper middle income', 'IBRD only', 'IDA & IBRD total', 'IDA total', 'IDA blend',
    'OECD members', 'OECD Member Countries',
    'Other Advanced Economies', 'Other small states',
    'Heavily indebted poor countries (HIPC)', 'High income', 'Low income', 'Lower middle income',
    'Low & middle income', 'Post-demographic dividend', 'Pre-demographic dividend',
    'Fragile and conflict affected situations', 'East Asia & Pacific (IDA & IBRD countries)',
    'Latin America & the Caribbean (IDA & IBRD countries)',
    'Middle East & North Africa (IDA & IBRD countries)', '(WHO) Africa Region',
    '(WHO) America Region', '(WHO) South-East Asia Region',
    '(WHO) Eastern Mediterranean Region', '(WHO) European Region',
    '(WHO) Western Pacific Region', 'Unknown or unspecified', 'Arab World',
    'Developed Asia', 'Early-demographic dividend', 'FAO (Food and Agriculture Organization)',
    'IDA only', 'Late-demographic dividend', 'Middle income',
    'Middle East & North Africa (excluding high income)',
    'World Bank Group', 'Western Europe', 'World',
    'European Union', 'Euro Area', 'Sub-Saharan Africa', 'North America',
    'South Asia']

wb = wb[~wb['country'].isin(country_groups)].reset_index(drop=True)

# %%
country_mapping = {
    'Bahamas, The': 'Bahamas',
    "Côte d'Ivoire": "Cote d'Ivoire",
    'Cabo Verde': 'Cape Verde',
    'Congo, Dem. Rep.': "Congo, Dem. People's Rep.",
    'Congo, Rep.': 'Congo, Rep.',
    'Korea, Rep.': 'Korea, South',
    'Korea, Dem. Rep.': "Korea, Dem. People's Rep.",
    'Lao PDR': 'Laos',
    'Micronesia, Fed. Sts.': 'Micronesia',
    'Myanmar': 'Burma',
    'São Tomé and Principe': 'Sao Tome and Principe',
    'Eswatini': 'Swaziland',
    'Taiwan, China': 'Taiwan',
    'Venezuela, RB': 'Venezuela',
    'Turkiye': 'Turkey',
    'Vietnam': 'Viet Nam',
    'Yemen, Rep.': 'Yemen',
    'Macao SAR, China': 'Macau',
    'West Bank and Gaza': 'Palestine',
    'Virgin Islands (U.S.)': 'United States Virgin Islands',
    'Saint Vincent and the Grenadines': 'St. Vincent and the Grenadines',
    'Netherlands Antilles (former)': 'Netherlands Antilles',
    'Réunion': 'Reunion',
    'Palestinian Authority Administered Territories': 'Palestine',
    'Palestinian Authority-Administered Territories': 'Palestine'
}

df6['country'] = df6['country'].replace(country_mapping)
wb['country'] = wb['country'].replace(country_mapping)

df7 = pd.merge(df6, wb, on=['country', 'year'], how='outer')

def check_countries(column, min_length=5):
    similar_pairs = []
    for i in range(len(column)):
        for j in range(i + 1, len(column)):
            if column[i] != column[j]:  # Ensure that identical countries are excluded
                seq = difflib.SequenceMatcher(None, column[i], column[j])
                match = seq.find_longest_match(0, len(column[i]), 0, len(column[j]))
                if match.size >= min_length:
                    similar_pairs.append((column[i], column[j], column[i][match.a: match.a + match.size]))
    return similar_pairs

check_countries(df7['country'].unique())
# Out:
# [('Algeria', 'Nigeria', 'geria'),
#  ('Australia', 'Austria', 'Austr'),
#  ('Austria', 'Transnistria', 'stria'),
#  ('Bosnia and Herzegovina', 'Trinidad and Tobago', ' and '),
#  ('Bosnia and Herzegovina', 'St. Vincent and the Grenadines', ' and '),
#  ('Bosnia and Herzegovina', 'Sao Tome and Principe', ' and '),
#  ('Bosnia and Herzegovina', 'Antigua and Barbuda', 'a and '),
#  ('Bosnia and Herzegovina', 'Serbia and Montenegro', 'ia and '),
#  ('Bosnia and Herzegovina', 'St. Kitts and Nevis', ' and '),
#  ('Bosnia and Herzegovina', 'Saint Kitts and Nevis', ' and '),
#  ('Bosnia and Herzegovina', 'Turks and Caicos Islands', ' and '),
#  ('Central African Republic', 'Czech Republic', ' Republic'),
#  ('Central African Republic', 'Dominican Republic', 'ican Republic'),
#  ('Central African Republic', 'Kyrgyz Republic', ' Republic'),
#  ('Central African Republic', 'Slovak Republic', ' Republic'),
#  ('Central African Republic', 'South Africa', ' Africa'),
#  ('Central African Republic', 'Syrian Arab Republic', ' Republic'),
#  ('Central African Republic', 'German Federal Republic', ' Republic'),
#  ('Central African Republic', 'American Samoa', 'rican '),
#  ('China', 'Hong Kong SAR, China', 'China'),
#  ("Congo, Dem. People's Rep.", 'Congo, Rep.', 'Congo, '),
#  ("Congo, Dem. People's Rep.", 'Egypt, Arab Rep.', ' Rep.'),
#  ("Congo, Dem. People's Rep.",
#   "Korea, Dem. People's Rep.",
#   ", Dem. People's Rep."),
#  ("Congo, Dem. People's Rep.", 'Congo (Brazzaville)', 'Congo'),
#  ("Congo, Dem. People's Rep.", 'Congo', 'Congo'),
#  ("Congo, Dem. People's Rep.", 'Iran, Islamic Rep.', ' Rep.'),
#  ('Congo, Rep.', 'Egypt, Arab Rep.', ' Rep.'),
#  ('Congo, Rep.', "Korea, Dem. People's Rep.", ' Rep.'),
#  ('Congo, Rep.', 'Congo (Brazzaville)', 'Congo'),
#  ('Congo, Rep.', 'Congo', 'Congo'),
#  ('Congo, Rep.', 'Iran, Islamic Rep.', ' Rep.'),
#  ('Czech Republic', 'Dominican Republic', ' Republic'),
#  ('Czech Republic', 'Kyrgyz Republic', ' Republic'),
#  ('Czech Republic', 'Slovak Republic', ' Republic'),
#  ('Czech Republic', 'Syrian Arab Republic', ' Republic'),
#  ('Czech Republic', 'Czechoslovakia', 'Czech'),
#  ('Czech Republic', 'German Federal Republic', ' Republic'),
#  ('Dominican Republic', 'Kyrgyz Republic', ' Republic'),
#  ('Dominican Republic', 'Slovak Republic', ' Republic'),
#  ('Dominican Republic', 'Syrian Arab Republic', ' Republic'),
#  ('Dominican Republic', 'Dominica', 'Dominica'),
#  ('Dominican Republic', 'German Federal Republic', ' Republic'),
#  ('Dominican Republic', 'American Samoa', 'ican '),
#  ('Egypt, Arab Rep.', 'Saudi Arabia', ' Arab'),
#  ('Egypt, Arab Rep.', 'Syrian Arab Republic', ' Arab Rep'),
#  ('Egypt, Arab Rep.', 'United Arab Emirates', ' Arab '),
#  ('Egypt, Arab Rep.', "Korea, Dem. People's Rep.", ' Rep.'),
#  ('Egypt, Arab Rep.', 'Iran, Islamic Rep.', ' Rep.'),
#  ('Swaziland', 'Thailand', 'iland'),
#  ('Swaziland', 'Somaliland', 'iland'),
#  ('Finland', 'Greenland', 'nland'),
#  ('Gambia, The', 'Zambia', 'ambia'),
#  ('Germany', 'Germany East', 'Germany'),
#  ('Germany', 'German Federal Republic', 'German'),
#  ('Guinea', 'Guinea-Bissau', 'Guinea'),
#  ('Guinea', 'Papua New Guinea', 'Guinea'),
#  ('Guinea', 'Equatorial Guinea', 'Guinea'),
#  ('Guinea-Bissau', 'Papua New Guinea', 'Guinea'),
#  ('Guinea-Bissau', 'Equatorial Guinea', 'Guinea'),
#  ('Iceland', 'Ireland', 'eland'),
#  ('India', 'Indian Kashmir', 'India'),
#  ('Indonesia', 'Micronesia', 'onesia'),
#  ('Indonesia', 'French Polynesia', 'nesia'),
#  ('Israel', 'Israeli-Occupied Territories', 'Israel'),
#  ('Israel', 'Israel in Occupied Territories', 'Israel'),
#  ('Israel', 'Israel in pre-1967 borders', 'Israel'),
#  ('Korea, South', 'South Africa', 'South'),
#  ('Korea, South', "Korea, Dem. People's Rep.", 'Korea, '),
#  ('Korea, South', 'South Sudan', 'South'),
#  ('Korea, South', 'South Ossetia', 'South'),
#  ('Kyrgyz Republic', 'Slovak Republic', ' Republic'),
#  ('Kyrgyz Republic', 'Syrian Arab Republic', ' Republic'),
#  ('Kyrgyz Republic', 'German Federal Republic', ' Republic'),
#  ('Mauritania', 'Mauritius', 'Maurit'),
#  ('Montenegro', 'Serbia and Montenegro', 'Montenegro'),
#  ('Netherlands', 'Switzerland', 'erland'),
#  ('Netherlands', 'Solomon Islands', 'lands'),
#  ('Netherlands', 'Marshall Islands', 'lands'),
#  ('Netherlands', 'Cayman Islands', 'lands'),
#  ('Netherlands', 'Cook Islands', 'lands'),
#  ('Netherlands', 'Jersey, Channel Islands', 'lands'),
#  ('Netherlands', 'Netherlands Antilles', 'Netherlands'),
#  ('Netherlands', 'United States Virgin Islands', 'lands'),
#  ('Netherlands', 'Channel Islands', 'lands'),
#  ('Netherlands', 'Faroe Islands', 'lands'),
#  ('Netherlands', 'Northern Mariana Islands', 'lands'),
#  ('Netherlands', 'Turks and Caicos Islands', 'lands'),
#  ('Netherlands', 'British Virgin Islands', 'lands'),
#  ('Nicaragua', 'Paraguay', 'aragua'),
#  ('Niger', 'Nigeria', 'Niger'),
#  ('North Macedonia', 'Northern Mariana Islands', 'North'),
#  ('North Macedonia', 'New Caledonia', 'edonia'),
#  ('Pakistan', 'Tajikistan', 'kistan'),
#  ('Pakistan', 'Afghanistan', 'istan'),
#  ('Pakistan', 'Turkmenistan', 'istan'),
#  ('Pakistan', 'Uzbekistan', 'kistan'),
#  ('Pakistan', 'Pakistani Kashmir', 'Pakistan'),
#  ('Papua New Guinea', 'Equatorial Guinea', ' Guinea'),
#  ('Russian Federation', 'German Federal Republic', 'an Federa'),
#  ('Russian Federation', 'Russia-Occupied Areas (Ukraine)', 'Russia'),
#  ('Saudi Arabia', 'Syrian Arab Republic', ' Arab'),
#  ('Saudi Arabia', 'United Arab Emirates', ' Arab'),
#  ('Serbia', 'Serbia and Montenegro', 'Serbia'),
#  ('Slovak Republic', 'Syrian Arab Republic', ' Republic'),
#  ('Slovak Republic', 'Czechoslovakia', 'lovak'),
#  ('Slovak Republic', 'German Federal Republic', ' Republic'),
#  ('Slovak Republic', 'Slovakia', 'Slovak'),
#  ('Somalia', 'Somaliland', 'Somali'),
#  ('South Africa', 'South Sudan', 'South '),
#  ('South Africa', 'South Ossetia', 'South '),
#  ('Sudan', 'South Sudan', 'Sudan'),
#  ('Switzerland', 'Netherlands Antilles', 'erland'),
#  ('Syrian Arab Republic', 'United Arab Emirates', ' Arab '),
#  ('Syrian Arab Republic', 'German Federal Republic', ' Republic'),
#  ('Tajikistan', 'Afghanistan', 'istan'),
#  ('Tajikistan', 'Turkmenistan', 'istan'),
#  ('Tajikistan', 'Uzbekistan', 'kistan'),
#  ('Tajikistan', 'Pakistani Kashmir', 'kistan'),
#  ('Thailand', 'Somaliland', 'iland'),
#  ('Trinidad and Tobago', 'St. Vincent and the Grenadines', ' and '),
#  ('Trinidad and Tobago', 'Sao Tome and Principe', ' and '),
#  ('Trinidad and Tobago', 'Antigua and Barbuda', ' and '),
#  ('Trinidad and Tobago', 'Serbia and Montenegro', ' and '),
#  ('Trinidad and Tobago', 'St. Kitts and Nevis', ' and '),
#  ('Trinidad and Tobago', 'Saint Kitts and Nevis', ' and '),
#  ('Trinidad and Tobago', 'Turks and Caicos Islands', ' and '),
#  ('Ukraine', 'Russia-Occupied Areas (Ukraine)', 'Ukraine'),
#  ('United Arab Emirates', 'United Kingdom', 'United '),
#  ('United Arab Emirates', 'United States', 'United '),
#  ('United Arab Emirates', 'Russia-Occupied Areas (Ukraine)', 'ed Ar'),
#  ('United Arab Emirates', 'United States Virgin Islands', 'United '),
#  ('United Kingdom', 'United States', 'United '),
#  ('United Kingdom', 'United States Virgin Islands', 'United '),
#  ('United States', 'Palestine, State of', ' State'),
#  ('United States', 'United States Virgin Islands', 'United States'),
#  ('Afghanistan', 'Turkmenistan', 'nistan'),
#  ('Afghanistan', 'Uzbekistan', 'istan'),
#  ('Afghanistan', 'Pakistani Kashmir', 'istan'),
#  ('Grenada', 'St. Vincent and the Grenadines', 'Grenad'),
#  ("Korea, Dem. People's Rep.", 'Iran, Islamic Rep.', ' Rep.'),
#  ('St. Vincent and the Grenadines', 'Sao Tome and Principe', ' and '),
#  ('St. Vincent and the Grenadines', 'Antigua and Barbuda', ' and '),
#  ('St. Vincent and the Grenadines', 'Serbia and Montenegro', ' and '),
#  ('St. Vincent and the Grenadines', 'St. Kitts and Nevis', ' and '),
#  ('St. Vincent and the Grenadines', 'Saint Kitts and Nevis', ' and '),
#  ('St. Vincent and the Grenadines', 'Turks and Caicos Islands', ' and '),
#  ('Sao Tome and Principe', 'Antigua and Barbuda', ' and '),
#  ('Sao Tome and Principe', 'Serbia and Montenegro', ' and '),
#  ('Sao Tome and Principe', 'St. Kitts and Nevis', ' and '),
#  ('Sao Tome and Principe', 'Saint Kitts and Nevis', ' and '),
#  ('Sao Tome and Principe', 'Turks and Caicos Islands', ' and '),
#  ('Solomon Islands', 'Marshall Islands', ' Islands'),
#  ('Solomon Islands', 'Cayman Islands', 'n Islands'),
#  ('Solomon Islands', 'Cook Islands', ' Islands'),
#  ('Solomon Islands', 'Iran, Islamic Rep.', ' Isla'),
#  ('Solomon Islands', 'Jersey, Channel Islands', ' Islands'),
#  ('Solomon Islands', 'Netherlands Antilles', 'lands'),
#  ('Solomon Islands', 'United States Virgin Islands', 'n Islands'),
#  ('Solomon Islands', 'Channel Islands', ' Islands'),
#  ('Solomon Islands', 'Faroe Islands', ' Islands'),
#  ('Solomon Islands', 'Northern Mariana Islands', ' Islands'),
#  ('Solomon Islands', 'Turks and Caicos Islands', ' Islands'),
#  ('Solomon Islands', 'British Virgin Islands', 'n Islands'),
#  ('South Sudan', 'South Ossetia', 'South '),
#  ('Turkmenistan', 'Uzbekistan', 'istan'),
#  ('Turkmenistan', 'Pakistani Kashmir', 'istan'),
#  ('Uzbekistan', 'Pakistani Kashmir', 'kistan'),
#  ('Antigua and Barbuda', 'Serbia and Montenegro', 'a and '),
#  ('Antigua and Barbuda', 'St. Kitts and Nevis', ' and '),
#  ('Antigua and Barbuda', 'Saint Kitts and Nevis', ' and '),
#  ('Antigua and Barbuda', 'Turks and Caicos Islands', ' and '),
#  ('Eastern Donbas', 'Western Sahara', 'stern '),
#  ('Gaza Strip', 'Gaza (Hamas)', 'Gaza '),
#  ('Indian Kashmir', 'Pakistani Kashmir', ' Kashmir'),
#  ('Israeli-Occupied Territories',
#   'Israel in Occupied Territories',
#   'Occupied Territories'),
#  ('Israeli-Occupied Territories', 'Israel in pre-1967 borders', 'Israel'),
#  ('Israeli-Occupied Territories',
#   'Russia-Occupied Areas (Ukraine)',
#   '-Occupied '),
#  ('Marshall Islands', 'Cayman Islands', ' Islands'),
#  ('Marshall Islands', 'Cook Islands', ' Islands'),
#  ('Marshall Islands', 'Iran, Islamic Rep.', ' Isla'),
#  ('Marshall Islands', 'Jersey, Channel Islands', 'l Islands'),
#  ('Marshall Islands', 'Netherlands Antilles', 'lands'),
#  ('Marshall Islands', 'United States Virgin Islands', ' Islands'),
#  ('Marshall Islands', 'Channel Islands', 'l Islands'),
#  ('Marshall Islands', 'Faroe Islands', ' Islands'),
#  ('Marshall Islands', 'Northern Mariana Islands', ' Islands'),
#  ('Marshall Islands', 'Turks and Caicos Islands', ' Islands'),
#  ('Marshall Islands', 'British Virgin Islands', ' Islands'),
#  ('Micronesia', 'French Polynesia', 'nesia'),
#  ('Palestine', 'Palestine, State of', 'Palestine'),
#  ('Samoa', 'American Samoa', 'Samoa'),
#  ('San Marino', 'Northern Mariana Islands', 'n Mari'),
#  ('Serbia and Montenegro', 'St. Kitts and Nevis', ' and '),
#  ('Serbia and Montenegro', 'Saint Kitts and Nevis', ' and '),
#  ('Serbia and Montenegro', 'Turks and Caicos Islands', ' and '),
#  ('St. Kitts and Nevis', 'Saint Kitts and Nevis', ' Kitts and Nevis'),
#  ('St. Kitts and Nevis', 'Turks and Caicos Islands', 's and '),
#  ('Congo (Brazzaville)', 'Congo', 'Congo'),
#  ('Czechoslovakia', 'Slovakia', 'lovakia'),
#  ('Germany East', 'German Federal Republic', 'German'),
#  ('European Union', 'Soviet Union', ' Union'),
#  ('Israel in Occupied Territories',
#   'Israel in pre-1967 borders',
#   'Israel in '),
#  ('Israel in Occupied Territories',
#   'Russia-Occupied Areas (Ukraine)',
#   'Occupied '),
#  ('Palestine, State of', 'United States Virgin Islands', ' State'),
#  ('Saint Kitts and Nevis', 'Turks and Caicos Islands', 's and '),
#  ('Cayman Islands', 'Cook Islands', ' Islands'),
#  ('Cayman Islands', 'Iran, Islamic Rep.', ' Isla'),
#  ('Cayman Islands', 'Jersey, Channel Islands', ' Islands'),
#  ('Cayman Islands', 'Netherlands Antilles', 'lands'),
#  ('Cayman Islands', 'United States Virgin Islands', 'n Islands'),
#  ('Cayman Islands', 'Channel Islands', ' Islands'),
#  ('Cayman Islands', 'Faroe Islands', ' Islands'),
#  ('Cayman Islands', 'Northern Mariana Islands', ' Islands'),
#  ('Cayman Islands', 'Turks and Caicos Islands', ' Islands'),
#  ('Cayman Islands', 'British Virgin Islands', 'n Islands'),
#  ('Cook Islands', 'Iran, Islamic Rep.', ' Isla'),
#  ('Cook Islands', 'Jersey, Channel Islands', ' Islands'),
#  ('Cook Islands', 'Netherlands Antilles', 'lands'),
#  ('Cook Islands', 'United States Virgin Islands', ' Islands'),
#  ('Cook Islands', 'Channel Islands', ' Islands'),
#  ('Cook Islands', 'Faroe Islands', ' Islands'),
#  ('Cook Islands', 'Northern Mariana Islands', ' Islands'),
#  ('Cook Islands', 'Turks and Caicos Islands', ' Islands'),
#  ('Cook Islands', 'British Virgin Islands', ' Islands'),
#  ('French Guiana', 'St. Martin (French part)', 'French '),
#  ('French Guiana', 'French Polynesia', 'French '),
#  ('Iran, Islamic Rep.', 'Jersey, Channel Islands', ' Isla'),
#  ('Iran, Islamic Rep.', 'United States Virgin Islands', ' Isla'),
#  ('Iran, Islamic Rep.', 'Channel Islands', ' Isla'),
#  ('Iran, Islamic Rep.', 'Faroe Islands', ' Isla'),
#  ('Iran, Islamic Rep.', 'Northern Mariana Islands', ' Isla'),
#  ('Iran, Islamic Rep.', 'Turks and Caicos Islands', ' Isla'),
#  ('Iran, Islamic Rep.', 'British Virgin Islands', ' Isla'),
#  ('Jersey, Channel Islands', 'Netherlands Antilles', 'lands'),
#  ('Jersey, Channel Islands', 'United States Virgin Islands', ' Islands'),
#  ('Jersey, Channel Islands', 'Channel Islands', 'Channel Islands'),
#  ('Jersey, Channel Islands', 'Faroe Islands', ' Islands'),
#  ('Jersey, Channel Islands', 'Northern Mariana Islands', ' Islands'),
#  ('Jersey, Channel Islands', 'Turks and Caicos Islands', ' Islands'),
#  ('Jersey, Channel Islands', 'British Virgin Islands', ' Islands'),
#  ('Martinique', 'St. Martin (French part)', 'Martin'),
#  ('Netherlands Antilles', 'United States Virgin Islands', 'lands'),
#  ('Netherlands Antilles', 'Channel Islands', 'lands'),
#  ('Netherlands Antilles', 'Faroe Islands', 'lands'),
#  ('Netherlands Antilles', 'Northern Mariana Islands', 'lands'),
#  ('Netherlands Antilles', 'Turks and Caicos Islands', 'lands'),
#  ('Netherlands Antilles', 'British Virgin Islands', 'lands'),
#  ('United States Virgin Islands', 'Channel Islands', ' Islands'),
#  ('United States Virgin Islands', 'Faroe Islands', ' Islands'),
#  ('United States Virgin Islands', 'Northern Mariana Islands', ' Islands'),
#  ('United States Virgin Islands', 'Turks and Caicos Islands', ' Islands'),
#  ('United States Virgin Islands', 'British Virgin Islands', ' Virgin Islands'),
#  ('Channel Islands', 'Faroe Islands', ' Islands'),
#  ('Channel Islands', 'Northern Mariana Islands', ' Islands'),
#  ('Channel Islands', 'Turks and Caicos Islands', ' Islands'),
#  ('Channel Islands', 'British Virgin Islands', ' Islands'),
#  ('Faroe Islands', 'Northern Mariana Islands', ' Islands'),
#  ('Faroe Islands', 'Turks and Caicos Islands', ' Islands'),
#  ('Faroe Islands', 'British Virgin Islands', ' Islands'),
#  ('St. Martin (French part)', 'French Polynesia', 'French '),
#  ('St. Martin (French part)', 'Sint Maarten (Dutch part)', 'ch part)'),
#  ('Northern Mariana Islands', 'Turks and Caicos Islands', ' Islands'),
#  ('Northern Mariana Islands', 'British Virgin Islands', ' Islands'),
#  ('Turks and Caicos Islands', 'British Virgin Islands', ' Islands')]

# %%
df7[df7.select_dtypes(exclude=['number']).columns.tolist()].head(1)
# Out:
#    country      world_bank_region region c/t? status country_code
# 0  Albania  Europe & Central Asia    NaN    c     PF          ALB

# %%
df7 = df7.drop(columns='country_code')

# %%
merged = df7.copy()
merged.to_pickle("smerged.dat")

# %% [markdown]
# ## Cleaning

# %%
# Load
merged = pd.read_pickle("saved/merged.dat")

# Sort
merged = merged.sort_values(by=['country', 'year']).reset_index(drop=True)

# %%
# Fill NaNs and unify
merged = merge_country_observations(merged, ['Iran'], ['Iran, Islamic Rep.'])
merged = merge_country_observations(merged, ['Slovak Republic'], ['Slovakia'])
merged = merge_country_observations(merged, ['Congo, Rep.'], ['Congo (Brazzaville)', 'Congo'])
merged = merge_country_observations(merged, ['Channel Islands'], ['Jersey, Channel Islands'])

merged = merge_country_observations(merged, ['Czech Republic', 'Slovakia'], ['Czechoslovakia'])
merged = merge_country_observations(merged, ['Germany'], ['Germany East', 'German Federal Republic'])
merged = merge_country_observations(merged, ['Serbia', 'Montenegro'], ['Serbia and Montenegro'])

merged = merge_country_observations(merged, ['Israel'], ['Israel in pre-1967 borders'])
merged = merge_country_observations(merged, ['Palestine'], ['Palestine, State of'])
merged = merge_country_observations(merged, ['Gaza Strip'], ['Gaza (Hamas)'])
merged = merge_country_observations(merged, ['West Bank'], ['Israeli-Occupied Territories', 'Israel in Occupied Territories'])
merged = merge_country_observations(merged, ['Palestine'], ['West Bank', 'Gaza Strip'])

merged = merge_country_observations(merged, ['Croatia', 'Serbia', 'Albania',
                                             'Kosovo', 'Bosnia and Herzegovina',
                                             'Montenegro', 'Slovenia',
                                             'North Macedonia'], ['Yugoslavia'])
merged = merge_country_observations(merged, ['Russian Federation', 'Estonia',
                                             'Lithuania', 'Latvia', 'Ukraine',
                                             'Belarus', 'Kazakhstan', 'Turkmenistan',
                                             'Tajikistan', 'Kyrgyz Republic', 'Azerbaijan',
                                             'Azerbaijan', 'Armenia', 'Uzbekistan',
                                             'Moldova'], ['Soviet Union'])
# Out:
# ['Iran'] ['Iran, Islamic Rep.']
# Elapsed time: 1.719426 seconds
# ['Slovak Republic'] ['Slovakia']
# Elapsed time: 1.569821 seconds
# ['Congo, Rep.'] ['Congo (Brazzaville)', 'Congo']
# Elapsed time: 1.544134 seconds
# ['Channel Islands'] ['Jersey, Channel Islands']
# Elapsed time: 1.522149 seconds
# ['Czech Republic', 'Slovakia'] ['Czechoslovakia']
# Elapsed time: 2.455398 seconds
# ['Germany'] ['Germany East', 'German Federal Republic']
# Elapsed time: 1.773499 seconds
# ['Serbia', 'Montenegro'] ['Serbia and Montenegro']
# Elapsed time: 2.874475 seconds
# ['Israel'] ['Israel in pre-1967 borders']
# Elapsed time: 1.51792 seconds
# ['Palestine'] ['Palestine, State of']
# Elapsed time: 1.640733 seconds
# ['Gaza Strip'] ['Gaza (Hamas)']
# Elapsed time: 1.137153 seconds
# ['West Bank'] ['Israeli-Occupied Territories', 'Israel in Occupied Territories']
# Elapsed time: 1.131995 seconds
# ['Palestine'] ['West Bank', 'Gaza Strip']
# Elapsed time: 1.508181 seconds
# ['Croatia', 'Serbia', 'Albania', 'Kosovo', 'Bosnia and Herzegovina', 'Montenegro', 'Slovenia', 'North Macedonia'] ['Yugoslavia']
# Elapsed time: 12.668945 seconds
# ['Russian Federation', 'Estonia', 'Lithuania', 'Latvia', 'Ukraine', 'Belarus', 'Kazakhstan', 'Turkmenistan', 'Tajikistan', 'Kyrgyz Republic', 'Azerbaijan', 'Azerbaijan', 'Armenia', 'Uzbekistan', 'Moldova'] ['Soviet Union']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 21
#      15 merged = merge_country_observations(merged, ['Palestine'], ['West Bank', 'Gaza Strip'])
#      17 merged = merge_country_observations(merged, ['Croatia', 'Serbia', 'Albania',
#      18                                              'Kosovo', 'Bosnia and Herzegovina',
#      19                                              'Montenegro', 'Slovenia',
#      20                                              'North Macedonia'], ['Yugoslavia'])
# ---> 21 merged = merge_country_observations(merged, ['Russian Federation', 'Estonia',
#      22                                              'Lithuania', 'Latvia', 'Ukraine',
#      23                                              'Belarus', 'Kazakhstan', 'Turkmenistan',
#      24                                              'Tajikistan', 'Kyrgyz Republic', 'Azerbaijan',
#      25                                              'Azerbaijan', 'Armenia', 'Uzbekistan',
#      26                                              'Moldova'], ['Soviet Union'])
#
# Cell In[1], line 22, in merge_country_observations(df, name1_list, name2_list)
#      20 for country in name1_list:
#      21     for column in numeric_columns:
# ---> 22         df.loc[df['country'] == country, column] = df.loc[df['country'] == country].apply(
#      23             lambda row: row[column]
#      24             if pd.notna(row[column])
#      25             else mean_values_by_year.loc[row['year'], column]
#      26             if row['year'] in mean_values_by_year.index else np.nan,  # Handle missing years
#      27             axis=1)
#      28 df = df[~df['country'].isin(name2_list)]
#      29 then = datetime.now()
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/series.py:6096, in Series._cmp_method(self, other, op)
#    6093 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6095 with np.errstate(all="ignore"):
# -> 6096     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6098 return self._construct_result(res_values, name=res_name)
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:293, in comparison_op(left, right, op)
#     290     return invalid_comparison(lvalues, rvalues, op)
#     292 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 293     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     295 else:
#     296     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:82, in comp_method_OBJECT_ARRAY(op, x, y)
#      80     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      81 else:
# ---> 82     result = libops.scalar_compare(x.ravel(), y, op)
#      83 return result.reshape(x.shape)
#
# KeyboardInterrupt:

# %%
# Check and drop countries over 90% NaNs
merged['nan_percentage'] = merged.isnull().mean(axis=1)
result = merged.groupby('country').apply(lambda x: (x['nan_percentage'] > 0.9).mean())
high_nan_countries = result[result > 0.9].index
print(high_nan_countries)
merged = merged[~merged['country'].isin(high_nan_countries)]
# Out:
# Index(['Abkhazia', 'Anguilla', 'Chechnya', 'Cook Islands', 'Crimea',
#        'Eastern Donbas', 'European Union', 'French Guiana', 'Indian Kashmir',
#        'Martinique', 'Nagorno-Karabakh', 'Netherlands Antilles', 'Niue',
#        'Pakistani Kashmir', 'Reunion', 'Russia-Occupied Areas (Ukraine)',
#        'Saint Kitts and Nevis', 'Somaliland', 'South Ossetia',
#        'St. Martin (French part)', 'Tibet', 'Transnistria', 'Western Sahara'],
#       dtype='object', name='country')

# %%
# Check and drop cols over 95% NaNs
nan_percentage = merged.isna().mean()
cols_to_remove = nan_percentage[nan_percentage > 0.95].index.tolist()
print(cols_to_remove)
merged = merged.drop(columns=cols_to_remove)
# Out:
# ['region', 'cpi_score_2022', 'cpi_rank', 'standard_error', 'number_of_sources', 'lower_ci', 'upper_ci', 'african_development_bank_cpia', 'bertelsmann_foundation_sustainable_governance_index', 'bertelsmann_foundation_transformation_index', 'economist_intelligence_unit_country_ratings', 'freedom_house_nations_in_transit', 'global_insights_country_risk_ratings', 'imd_world_competitiveness_yearbook', 'perc_asia_risk_guide', 'prs_international_country_risk_guide', 'varieties_of_democracy_project', 'world_bank_cpia', 'world_economic_forum_eos', 'world_justice_project_rule_of_law_index', 'interim', 'sf']

# %%
# Find region cols and rename
print([col for col in merged.columns if 'region' in col.lower()])
merged = merged.rename(columns={'world_bank_region':'region'})
# Out:
# ['world_bank_region']

# %%
# Fill NaNs in region col
merged['region'] = merged.groupby('country')['region'].transform(lambda x: x.fillna(x.mode().iloc[0] if not x.mode().empty else x))

# %%
# Manually fill rest
country_region_map = {
    'Afghanistan': 'Middle East & North Africa',
    'American Samoa': 'East Asia & Pacific',
    'Andorra': 'Europe & Central Asia',
    'Antigua and Barbuda': 'Latin America & the Caribbean',
    'Aruba': 'Latin America & the Caribbean',
    'Bermuda': 'Latin America & the Caribbean',
    'British Virgin Islands': 'Latin America & the Caribbean',
    'Cayman Islands': 'Latin America & the Caribbean',
    'Congo': 'Sub-Saharan Africa',
    'Cuba': 'Latin America & the Caribbean',
    'Curacao': 'Latin America & the Caribbean',
    'Dominica': 'Latin America & the Caribbean',
    'Equatorial Guinea': 'Sub-Saharan Africa',
    'Eritrea': 'Sub-Saharan Africa',
    'Faroe Islands': 'Europe & Central Asia',
    'French Polynesia': 'East Asia & Pacific',
    'Gibraltar': 'Europe & Central Asia',
    'Greenland': 'Europe & Central Asia',
    'Grenada': 'Latin America & the Caribbean',
    'Guam': 'East Asia & Pacific',
    'Isle of Man': 'Europe & Central Asia',
    'Channel Islands': 'Europe & Central Asia',
    'Kiribati': 'East Asia & Pacific',
    'Korea, Dem. People\'s Rep.': 'East Asia & Pacific',
    'Kosovo': 'Europe & Central Asia',
    'Liechtenstein': 'Europe & Central Asia',
    'Macau': 'East Asia & Pacific',
    'Maldives': 'South Asia',
    'Marshall Islands': 'East Asia & Pacific',
    'Micronesia': 'East Asia & Pacific',
    'Monaco': 'Europe & Central Asia',
    'Nauru': 'East Asia & Pacific',
    'New Caledonia': 'East Asia & Pacific',
    'Northern Mariana Islands': 'East Asia & Pacific',
    'Palau': 'East Asia & Pacific',
    'Palestine': 'Middle East & North Africa',
    'Puerto Rico': 'Latin America & the Caribbean',
    'Samoa': 'East Asia & Pacific',
    'San Marino': 'Europe & Central Asia',
    'Sao Tome and Principe': 'Sub-Saharan Africa',
    'Sint Maarten (Dutch part)': 'Latin America & the Caribbean',
    'Slovakia': 'Europe & Central Asia',
    'Solomon Islands': 'East Asia & Pacific',
    'South Sudan': 'Sub-Saharan Africa',
    'St. Kitts and Nevis': 'Latin America & the Caribbean',
    'St. Lucia': 'Latin America & the Caribbean',
    'St. Vincent and the Grenadines': 'Latin America & the Caribbean',
    'Tonga': 'East Asia & Pacific',
    'Turkmenistan': 'Europe & Central Asia',
    'Turks and Caicos Islands': 'Latin America & the Caribbean',
    'Tuvalu': 'East Asia & Pacific',
    'United States Virgin Islands': 'Latin America & the Caribbean',
    'Uzbekistan': 'Europe & Central Asia',
    'Vanuatu': 'East Asia & Pacific'}

merged['region'] = merged['country'].map(country_region_map).fillna(merged['region'])

# %%
c = merged[['country', 'region']].drop_duplicates()
nan_max_per_country = merged.groupby('country')['nan_percentage'].mean().reset_index()
c = c.merge(nan_max_per_country, on='country', how='left')
min_year = merged.groupby('country')['year'].min().reset_index()
c = c.merge(min_year, on='country', how='left')
c.sort_values(by='nan_percentage')
# Out:
#                        country                         region  nan_percentage  \
# 52                      Cyprus          Europe & Central Asia        0.451226
# 127                     Mexico  Latin America & the Caribbean        0.457917
# 154                       Peru  Latin America & the Caribbean        0.458423
# 43                    Colombia  Latin America & the Caribbean        0.458626
# 133                    Morocco     Middle East & North Africa        0.459031
# ..                         ...                            ...             ...
# 51                     Curacao  Latin America & the Caribbean        0.907402
# 40             Channel Islands          Europe & Central Asia        0.916678
# 172  Sint Maarten (Dutch part)  Latin America & the Caribbean        0.924063
# 145   Northern Mariana Islands            East Asia & Pacific        0.924132
# 94                 Isle of Man          Europe & Central Asia        0.926909
#
#      year
# 52   1960
# 127  1960
# 154  1960
# 43   1960
# 133  1960
# ..    ...
# 51   1960
# 40   1960
# 172  1960
# 145  1960
# 94   1960
#
# [217 rows x 4 columns]

# %%
merged.to_pickle("cleaned.dat")

# %% [markdown]
# # Fill NULLs, standardise and target

# %% [markdown]
# ## Fill NULLs

# %%
cleaned = pd.read_pickle("saved/cleaned.dat")

# %%
def fill_all_data(df, numeric_cols, country_col='country', region_col='region', year_col='year'):
    def forward_fill_country(group):
        print(group.country.unique())
        for col in numeric_cols:
            if col + '_fill' not in group.columns:
                group[col + '_fill'] = np.nan
            group[col + '_fill'] = group[col + '_fill'].where(group[col].isna(), group[year_col])
            group[col + '_fill'] = group[col + '_fill'].ffill()
            group[col] = group[col].ffill()
        return group

    def backward_fill_country(group):
        print(group.country.unique())
        for col in numeric_cols:
            mask_still_na = group[col].isna()
            next_valid_year = group[year_col].where(group[col].notna()).bfill()
            fill_idx = mask_still_na & group[col + '_fill'].isna()
            group.loc[fill_idx, col + '_fill'] = next_valid_year
            group[col] = group[col].bfill()
        return group

    print("\n-------------------------- FFILL --------------------------")
    df = df.groupby(country_col, group_keys=False).apply(forward_fill_country)
    print("\n-------------------------- BFILL --------------------------")
    df = df.groupby(country_col, group_keys=False).apply(backward_fill_country)

    print("\n-------------------------- orig REGION FILL --------------------------")
    for col in numeric_cols:
        orig_df = df[df[col + '_fill']==df['year']]
        df['_region_year_mean'] = orig_df.groupby([region_col, year_col])[col].transform('mean')
        mask_still_na = df[col].isna()
        df.loc[mask_still_na, col] = df.loc[mask_still_na, '_region_year_mean']
        just_filled = mask_still_na & df[col].notna()
        df.loc[just_filled, col + '_fill'] = -df.loc[just_filled, year_col]
        df.drop(columns='_region_year_mean', inplace=True)

    print("\n-------------------------- orig WORLD FILL --------------------------")
    for col in numeric_cols:
        orig_df = df[df[col + '_fill']==df['year']]
        df['_world_year_mean'] = orig_df.groupby(year_col)[col].transform('mean')
        mask_still_na = df[col].isna()
        df.loc[mask_still_na, col] = df.loc[mask_still_na, '_world_year_mean']
        just_filled = mask_still_na & df[col].notna()
        df.loc[just_filled, col + '_fill'] = 0
        df.drop(columns='_world_year_mean', inplace=True)
        
    print("\n-------------------------- rest REGION FILL --------------------------")
    for col in numeric_cols:
        df['_region_year_mean'] = df.groupby([region_col, year_col])[col].transform('mean')
        mask_still_na = df[col].isna()
        df.loc[mask_still_na, col] = df.loc[mask_still_na, '_region_year_mean']
        just_filled = mask_still_na & df[col].notna()
        df.loc[just_filled, col + '_fill'] = -df.loc[just_filled, year_col]
        df.drop(columns='_region_year_mean', inplace=True)

    print("\n-------------------------- rest WORLD FILL --------------------------")
    for col in numeric_cols:
        df['_world_year_mean'] = df.groupby(year_col)[col].transform('mean')
        mask_still_na = df[col].isna()
        df.loc[mask_still_na, col] = df.loc[mask_still_na, '_world_year_mean']
        just_filled = mask_still_na & df[col].notna()
        df.loc[just_filled, col + '_fill'] = 0
        df.drop(columns='_world_year_mean', inplace=True)

    return df

# %%
numeric_cols = [
    col for col in cleaned.columns 
    if col not in ['country','year', 'nan_percentage'] 
    and pd.api.types.is_numeric_dtype(merged[col])
]

filled = fill_all_data(
    cleaned,
    numeric_cols=numeric_cols,
    country_col='country',
    region_col='region',
    year_col='year'
)
# Out:
# -------------------------- FFILL --------------------------
# ['Afghanistan']
# ['Albania']
# ['Algeria']
# ['American Samoa']
# ['Andorra']
# ['Angola']
# ['Antigua and Barbuda']
# ['Argentina']
# ['Armenia']
# ['Aruba']
# ['Australia']
# ['Austria']
# ['Azerbaijan']
# ['Bahamas']
# ['Bahrain']
# ['Bangladesh']
# ['Barbados']
# ['Belarus']
# ['Belgium']
# ['Belize']
# ['Benin']
# ['Bermuda']
# ['Bhutan']
# ['Bolivia']
# ['Bosnia and Herzegovina']
# ['Botswana']
# ['Brazil']
# ['British Virgin Islands']
# ['Brunei Darussalam']
# ['Bulgaria']
# ['Burkina Faso']
# ['Burma']
# ['Burundi']
# ['Cambodia']
# ['Cameroon']
# ['Canada']
# ['Cape Verde']
# ['Cayman Islands']
# ['Central African Republic']
# ['Chad']
# ['Channel Islands']
# ['Chile']
# ['China']
# ['Colombia']
# ['Comoros']
# ["Congo, Dem. People's Rep."]
# ['Congo, Rep.']
# ['Costa Rica']
# ["Cote d'Ivoire"]
# ['Croatia']
# ['Cuba']
# ['Curacao']
# ['Cyprus']
# ['Czech Republic']
# ['Denmark']
# ['Djibouti']
# ['Dominica']
# ['Dominican Republic']
# ['Ecuador']
# ['Egypt, Arab Rep.']
# ['El Salvador']
# ['Equatorial Guinea']
# ['Eritrea']
# ['Estonia']
# ['Ethiopia']
# ['Faroe Islands']
# ['Fiji']
# ['Finland']
# ['France']
# ['French Polynesia']
# ['Gabon']
# ['Gambia, The']
# ['Georgia']
# ['Germany']
# ['Ghana']
# ['Gibraltar']
# ['Greece']
# ['Greenland']
# ['Grenada']
# ['Guam']
# ['Guatemala']
# ['Guinea']
# ['Guinea-Bissau']
# ['Guyana']
# ['Haiti']
# ['Honduras']
# ['Hong Kong SAR, China']
# ['Hungary']
# ['Iceland']
# ['India']
# ['Indonesia']
# ['Iran']
# ['Iraq']
# ['Ireland']
# ['Isle of Man']
# ['Israel']
# ['Italy']
# ['Jamaica']
# ['Japan']
# ['Jordan']
# ['Kazakhstan']
# ['Kenya']
# ['Kiribati']
# ["Korea, Dem. People's Rep."]
# ['Korea, South']
# ['Kosovo']
# ['Kuwait']
# ['Kyrgyz Republic']
# ['Laos']
# ['Latvia']
# ['Lebanon']
# ['Lesotho']
# ['Liberia']
# ['Libya']
# ['Liechtenstein']
# ['Lithuania']
# ['Luxembourg']
# ['Macau']
# ['Madagascar']
# ['Malawi']
# ['Malaysia']
# ['Maldives']
# ['Mali']
# ['Malta']
# ['Marshall Islands']
# ['Mauritania']
# ['Mauritius']
# ['Mexico']
# ['Micronesia']
# ['Moldova']
# ['Monaco']
# ['Mongolia']
# ['Montenegro']
# ['Morocco']
# ['Mozambique']
# ['Namibia']
# ['Nauru']
# ['Nepal']
# ['Netherlands']
# ['New Caledonia']
# ['New Zealand']
# ['Nicaragua']
# ['Niger']
# ['Nigeria']
# ['North Macedonia']
# ['Northern Mariana Islands']
# ['Norway']
# ['Oman']
# ['Pakistan']
# ['Palau']
# ['Palestine']
# ['Panama']
# ['Papua New Guinea']
# ['Paraguay']
# ['Peru']
# ['Philippines']
# ['Poland']
# ['Portugal']
# ['Puerto Rico']
# ['Qatar']
# ['Romania']
# ['Russian Federation']
# ['Rwanda']
# ['Samoa']
# ['San Marino']
# ['Sao Tome and Principe']
# ['Saudi Arabia']
# ['Senegal']
# ['Serbia']
# ['Seychelles']
# ['Sierra Leone']
# ['Singapore']
# ['Sint Maarten (Dutch part)']
# ['Slovak Republic']
# ['Slovenia']
# ['Solomon Islands']
# ['Somalia']
# ['South Africa']
# ['South Sudan']
# ['Spain']
# ['Sri Lanka']
# ['St. Kitts and Nevis']
# ['St. Lucia']
# ['St. Vincent and the Grenadines']
# ['Sudan']
# ['Suriname']
# ['Swaziland']
# ['Sweden']
# ['Switzerland']
# ['Syrian Arab Republic']
# ['Taiwan']
# ['Tajikistan']
# ['Tanzania']
# ['Thailand']
# ['Timor-Leste']
# ['Togo']
# ['Tonga']
# ['Trinidad and Tobago']
# ['Tunisia']
# ['Turkey']
# ['Turkmenistan']
# ['Turks and Caicos Islands']
# ['Tuvalu']
# ['Uganda']
# ['Ukraine']
# ['United Arab Emirates']
# ['United Kingdom']
# ['United States']
# ['United States Virgin Islands']
# ['Uruguay']
# ['Uzbekistan']
# ['Vanuatu']
# ['Venezuela']
# ['Viet Nam']
# ['Yemen']
# ['Zambia']
# ['Zimbabwe']
#
# -------------------------- BFILL --------------------------
# ['Afghanistan']
# ['Albania']
# ['Algeria']
# ['American Samoa']
# ['Andorra']
# ['Angola']
# ['Antigua and Barbuda']
# ['Argentina']
# ['Armenia']
# ['Aruba']
# ['Australia']
# ['Austria']
# ['Azerbaijan']
# ['Bahamas']
# ['Bahrain']
# ['Bangladesh']
# ['Barbados']
# ['Belarus']
# ['Belgium']
# ['Belize']
# ['Benin']
# ['Bermuda']
# ['Bhutan']
# ['Bolivia']
# ['Bosnia and Herzegovina']
# ['Botswana']
# ['Brazil']
# ['British Virgin Islands']
# ['Brunei Darussalam']
# ['Bulgaria']
# ['Burkina Faso']
# ['Burma']
# ['Burundi']
# ['Cambodia']
# ['Cameroon']
# ['Canada']
# ['Cape Verde']
# ['Cayman Islands']
# ['Central African Republic']
# ['Chad']
# ['Channel Islands']
# ['Chile']
# ['China']
# ['Colombia']
# ['Comoros']
# ["Congo, Dem. People's Rep."]
# ['Congo, Rep.']
# ['Costa Rica']
# ["Cote d'Ivoire"]
# ['Croatia']
# ['Cuba']
# ['Curacao']
# ['Cyprus']
# ['Czech Republic']
# ['Denmark']
# ['Djibouti']
# ['Dominica']
# ['Dominican Republic']
# ['Ecuador']
# ['Egypt, Arab Rep.']
# ['El Salvador']
# ['Equatorial Guinea']
# ['Eritrea']
# ['Estonia']
# ['Ethiopia']
# ['Faroe Islands']
# ['Fiji']
# ['Finland']
# ['France']
# ['French Polynesia']
# ['Gabon']
# ['Gambia, The']
# ['Georgia']
# ['Germany']
# ['Ghana']
# ['Gibraltar']
# ['Greece']
# ['Greenland']
# ['Grenada']
# ['Guam']
# ['Guatemala']
# ['Guinea']
# ['Guinea-Bissau']
# ['Guyana']
# ['Haiti']
# ['Honduras']
# ['Hong Kong SAR, China']
# ['Hungary']
# ['Iceland']
# ['India']
# ['Indonesia']
# ['Iran']
# ['Iraq']
# ['Ireland']
# ['Isle of Man']
# ['Israel']
# ['Italy']
# ['Jamaica']
# ['Japan']
# ['Jordan']
# ['Kazakhstan']
# ['Kenya']
# ['Kiribati']
# ["Korea, Dem. People's Rep."]
# ['Korea, South']
# ['Kosovo']
# ['Kuwait']
# ['Kyrgyz Republic']
# ['Laos']
# ['Latvia']
# ['Lebanon']
# ['Lesotho']
# ['Liberia']
# ['Libya']
# ['Liechtenstein']
# ['Lithuania']
# ['Luxembourg']
# ['Macau']
# ['Madagascar']
# ['Malawi']
# ['Malaysia']
# ['Maldives']
# ['Mali']
# ['Malta']
# ['Marshall Islands']
# ['Mauritania']
# ['Mauritius']
# ['Mexico']
# ['Micronesia']
# ['Moldova']
# ['Monaco']
# ['Mongolia']
# ['Montenegro']
# ['Morocco']
# ['Mozambique']
# ['Namibia']
# ['Nauru']
# ['Nepal']
# ['Netherlands']
# ['New Caledonia']
# ['New Zealand']
# ['Nicaragua']
# ['Niger']
# ['Nigeria']
# ['North Macedonia']
# ['Northern Mariana Islands']
# ['Norway']
# ['Oman']
# ['Pakistan']
# ['Palau']
# ['Palestine']
# ['Panama']
# ['Papua New Guinea']
# ['Paraguay']
# ['Peru']
# ['Philippines']
# ['Poland']
# ['Portugal']
# ['Puerto Rico']
# ['Qatar']
# ['Romania']
# ['Russian Federation']
# ['Rwanda']
# ['Samoa']
# ['San Marino']
# ['Sao Tome and Principe']
# ['Saudi Arabia']
# ['Senegal']
# ['Serbia']
# ['Seychelles']
# ['Sierra Leone']
# ['Singapore']
# ['Sint Maarten (Dutch part)']
# ['Slovak Republic']
# ['Slovenia']
# ['Solomon Islands']
# ['Somalia']
# ['South Africa']
# ['South Sudan']
# ['Spain']
# ['Sri Lanka']
# ['St. Kitts and Nevis']
# ['St. Lucia']
# ['St. Vincent and the Grenadines']
# ['Sudan']
# ['Suriname']
# ['Swaziland']
# ['Sweden']
# ['Switzerland']
# ['Syrian Arab Republic']
# ['Taiwan']
# ['Tajikistan']
# ['Tanzania']
# ['Thailand']
# ['Timor-Leste']
# ['Togo']
# ['Tonga']
# ['Trinidad and Tobago']
# ['Tunisia']
# ['Turkey']
# ['Turkmenistan']
# ['Turks and Caicos Islands']
# ['Tuvalu']
# ['Uganda']
# ['Ukraine']
# ['United Arab Emirates']
# ['United Kingdom']
# ['United States']
# ['United States Virgin Islands']
# ['Uruguay']
# ['Uzbekistan']
# ['Vanuatu']
# ['Venezuela']
# ['Viet Nam']
# ['Yemen']
# ['Zambia']
# ['Zimbabwe']
#
# -------------------------- orig REGION FILL --------------------------
#
# -------------------------- orig WORLD FILL --------------------------
#
# -------------------------- rest REGION FILL --------------------------
#
# -------------------------- rest WORLD FILL --------------------------

# %%
filled.to_pickle("saved/filled.dat")

# %% [markdown]
# ## Target
# Maybe the target should not have been filled beforehand \
# Can always just exclude those obs where target_fill != year

# %%
def calculate_gdp5(df, country, base_year):
    base_year = float(base_year)
    gdp_base = df.loc[(df['country'] == country) & (df['year'].astype(float) == base_year), 'NY.GDP.PCAP.CD']
    gdp_later = df.loc[(df['country'] == country) & (df['year'].astype(float) == base_year + 5), 'NY.GDP.PCAP.CD']
    if not gdp_base.empty and not gdp_later.empty:
        return ((gdp_later.values[0] - gdp_base.values[0]) / gdp_base.values[0]) * 100
    return None

df = pd.read_pickle("saved/filled.dat")
df['GDP5'] = df.apply(lambda row: calculate_gdp5(df, row['country'], row['year']) if float(row['year']) <= 2017 else None, axis=1)
df = df[df['GDP5'].notnull()]
df['GDP5'] = (df['GDP5'] / 5).round(0)

bins = [-float('inf'), 1, 6, 12, float('inf')]
labels = [0, 1, 2, 3]
df['GDP5_cat'] = pd.cut(df['GDP5'], bins=bins, labels=labels)

bins = [-float('inf'), 1, float('inf')]
labels = [0, 1]
df['GDP5_2cat'] = pd.cut(df['GDP5'], bins=bins, labels=labels)

df.to_pickle("saved/targeted.dat")

# %%
df[['country', 'year', 'NY.GDP.PCAP.CD', 'NY.GDP.PCAP.CD_fill', 'GDP5', 'GDP5_2cat']]
# Out:
#            country  year  NY.GDP.PCAP.CD  NY.GDP.PCAP.CD_fill  GDP5 GDP5_2cat
# 21     Afghanistan  1960       60.950364               1962.0  15.0         1
# 22     Afghanistan  1961       60.950364               1962.0  27.0         1
# 23     Afghanistan  1962       60.950364               1962.0  35.0         1
# 24     Afghanistan  1963       82.021738               1963.0  13.0         1
# 25     Afghanistan  1964       85.511073               1964.0  11.0         1
# ...            ...   ...             ...                  ...   ...       ...
# 15808     Zimbabwe  2013     1408.367810               2013.0  12.0         1
# 15809     Zimbabwe  2014     1407.034291               2014.0   0.0         0
# 15810     Zimbabwe  2015     1410.329173               2015.0  -1.0         0
# 15811     Zimbabwe  2016     1421.787791               2016.0   5.0         1
# 15812     Zimbabwe  2017     1192.107012               2017.0   8.0         1
#
# [13101 rows x 6 columns]

# %% [markdown]
# ## Standardise

# %%
df = pd.read_pickle("saved/targeted.dat")

# %%
geo = pd.read_pickle("dpWB.dat")[['country_name', 'NW_point_lon',
       'NW_point_lat', 'NE_point_lon', 'NE_point_lat', 'SE_point_lon',
       'SE_point_lat', 'SW_point_lon', 'SW_point_lat']]
geo = geo.rename(columns={'country_name':'country'})
geo = geo[geo.NW_point_lon.notnull()]

df = pd.merge(df, geo, on='country', how='left')

# %%
df['year_str'] = df['year'].astype(str)
df = df.sort_values(by=['country', 'year_str']).reset_index(drop=True)

dfst = standardize_dataframe(df, target='GDP5_cat', exclude=['year_str', 'GDP5', 'GDP5_2cat'])

dfst.fillna(0, inplace=True)
dfst.to_pickle("saved/ready.dat")

# %% [markdown]
# # Model setup

# %% [markdown]
# ## Train and test set

# %%
dfst = pd.read_pickle("saved/ready.dat")

# %%
dfst.columns
# Out:
# Index(['year', 'country', 'economic_freedom_summary_index', 'efw_rank',
#        'quartile', '1a_government_consumption', 'data',
#        '1b__transfers_and_subsidies', 'data.1', '1c__government_investment',
#        ...
#        'GDP5_2cat', 'NW_point_lon', 'NW_point_lat', 'NE_point_lon',
#        'NE_point_lat', 'SE_point_lon', 'SE_point_lat', 'SW_point_lon',
#        'SW_point_lat', 'year_str'],
#       dtype='object', length=890)

# %%
from sklearn.model_selection import train_test_split

dfst = pd.read_pickle("saved/ready.dat")
past_observation_count = 5
target_variable = 'GDP5_cat'
columns_to_exclude = ['GDP5_2cat', 'GDP5_cat', 'year_str', 'country', 'GDP5', 'region', 'c/t?', 'status']

target_array = []
explanatory_array = []

grouped = dfst.groupby('country')

for _, group_df in grouped:
    target_values = group_df[target_variable].values
    explanatory_values = group_df.drop(columns=columns_to_exclude).values
    for i in range(past_observation_count, len(target_values)):
        target_array.append(target_values[i])
        explanatory_array.append(explanatory_values[i - past_observation_count:i])

X = np.array(explanatory_array, dtype=np.float32)
y = np.array(target_array, dtype=np.int32)

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.1, random_state=36)

def relu(x):
    return np.clip(x,0,np.inf)
def softmax(x):
    return [np.exp(x[i])/np.sum(np.exp(x)) for i in range(len(x))]

# %% [markdown]
# ## Run model
# Is it correct that I have 10-90 validation split and 5-95 train-test split

# %%
from keras.layers import LSTM
from tensorflow.keras import datasets, layers, models
from tensorflow import keras

model = keras.Sequential([
    keras.layers.LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True),
    keras.layers.LSTM(50, return_sequences=False),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(17, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=300, batch_size=100, validation_split=0.1, callbacks=[keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)])
test_loss, test_acc = model.evaluate(X_test, y_test)
print('\nTest accuracy:', test_acc)
# Out:
# 2025-02-09 18:03:38.552487: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-02-09 18:03:38.918876: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-02-09 18:03:39.439476: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-09 18:03:47.940592: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Epoch 1/300
# 2025-02-09 18:04:01.210472: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 8913509640 exceeds 10% of free system memory.
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 32s 6ms/step - accuracy: 0.6992 - loss: 0.7166 - val_accuracy: 0.8665 - val_loss: 0.3221
# Epoch 2/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.8850 - loss: 0.2845 - val_accuracy: 0.9122 - val_loss: 0.2136
# Epoch 3/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9190 - loss: 0.2046 - val_accuracy: 0.9353 - val_loss: 0.1735
# Epoch 4/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9363 - loss: 0.1668 - val_accuracy: 0.9410 - val_loss: 0.1531
# Epoch 5/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9445 - loss: 0.1478 - val_accuracy: 0.9492 - val_loss: 0.1319
# Epoch 6/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9498 - loss: 0.1339 - val_accuracy: 0.9525 - val_loss: 0.1288
# Epoch 7/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9549 - loss: 0.1231 - val_accuracy: 0.9590 - val_loss: 0.1166
# Epoch 8/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9578 - loss: 0.1164 - val_accuracy: 0.9552 - val_loss: 0.1269
# Epoch 9/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9591 - loss: 0.1149 - val_accuracy: 0.9557 - val_loss: 0.1238
# Epoch 10/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9621 - loss: 0.1058 - val_accuracy: 0.9642 - val_loss: 0.1055
# Epoch 11/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9646 - loss: 0.0999 - val_accuracy: 0.9668 - val_loss: 0.0962
# Epoch 12/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9658 - loss: 0.0968 - val_accuracy: 0.9626 - val_loss: 0.1058
# Epoch 13/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9671 - loss: 0.0951 - val_accuracy: 0.9700 - val_loss: 0.0913
# Epoch 14/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9686 - loss: 0.0922 - val_accuracy: 0.9659 - val_loss: 0.0985
# Epoch 15/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9687 - loss: 0.0901 - val_accuracy: 0.9675 - val_loss: 0.0967
# Epoch 16/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9699 - loss: 0.0866 - val_accuracy: 0.9691 - val_loss: 0.0925
# Epoch 17/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9697 - loss: 0.0881 - val_accuracy: 0.9699 - val_loss: 0.0893
# Epoch 18/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9712 - loss: 0.0840 - val_accuracy: 0.9669 - val_loss: 0.0985
# Epoch 19/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9719 - loss: 0.0826 - val_accuracy: 0.9718 - val_loss: 0.0870
# Epoch 20/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9712 - loss: 0.0825 - val_accuracy: 0.9697 - val_loss: 0.0923
# Epoch 21/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9726 - loss: 0.0815 - val_accuracy: 0.9727 - val_loss: 0.0822
# Epoch 22/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9729 - loss: 0.0797 - val_accuracy: 0.9723 - val_loss: 0.0825
# Epoch 23/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9735 - loss: 0.0778 - val_accuracy: 0.9692 - val_loss: 0.0934
# Epoch 24/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 30s 6ms/step - accuracy: 0.9734 - loss: 0.0792 - val_accuracy: 0.9741 - val_loss: 0.0800
# Epoch 25/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9743 - loss: 0.0775 - val_accuracy: 0.9746 - val_loss: 0.0798
# Epoch 26/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9744 - loss: 0.0765 - val_accuracy: 0.9757 - val_loss: 0.0772
# Epoch 27/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9749 - loss: 0.0751 - val_accuracy: 0.9746 - val_loss: 0.0813
# Epoch 28/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9751 - loss: 0.0750 - val_accuracy: 0.9771 - val_loss: 0.0745
# Epoch 29/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9763 - loss: 0.0723 - val_accuracy: 0.9726 - val_loss: 0.0886
# Epoch 30/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9764 - loss: 0.0726 - val_accuracy: 0.9749 - val_loss: 0.0775
# Epoch 31/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9765 - loss: 0.0713 - val_accuracy: 0.9740 - val_loss: 0.0810
# Epoch 32/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9761 - loss: 0.0727 - val_accuracy: 0.9754 - val_loss: 0.0769
# Epoch 33/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9772 - loss: 0.0697 - val_accuracy: 0.9799 - val_loss: 0.0690
# Epoch 34/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9770 - loss: 0.0703 - val_accuracy: 0.9734 - val_loss: 0.0828
# Epoch 35/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 30s 6ms/step - accuracy: 0.9773 - loss: 0.0701 - val_accuracy: 0.9770 - val_loss: 0.0726
# Epoch 36/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9782 - loss: 0.0677 - val_accuracy: 0.9791 - val_loss: 0.0679
# Epoch 37/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9780 - loss: 0.0673 - val_accuracy: 0.9770 - val_loss: 0.0776
# Epoch 38/300
# 5054/5054 ━━━━━━━━━━━━━━━━━━━━ 29s 6ms/step - accuracy: 0.9788 - loss: 0.0660 - val_accuracy: 0.9802 - val_loss: 0.0694
# Epoch 39/300
# 4904/5054 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9786 - loss: 0.0675
